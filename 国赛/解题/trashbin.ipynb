# %%
def get_randoms(std_devs):
    """
    根据给定的标准差列表生成随机数列表。

    参数:
    std_devs (list): 包含每个随机数标准差的列表

    返回:
    list: 包含生成的随机数的列表，按以下顺序排列：
        - 小麦预期销售量增长率，介于0.05~0.1之间
        - 玉米预期销售量增长率，介于0.05~0.1之间
        - 其他农作物预期销售量相对于2023年的变化率，介于-0.05~+0.05之间
        - 农作物亩产量每年的变化率，介于-0.1~+0.1之间
        - 农作物种植成本每年的增长率，在0.05附近
        - 粮食类作物销售价格每年的增长率，在0附近
        - 蔬菜类作物销售价格每年的增长率，在0.05附近
        - 食用菌的销售价格每年的增长率，在-0.05~-0.01之间
        - 羊肚菌的销售价格每年下降幅度为5%
    """
    # 定义均值
    means = [
        (0.05 + 0.1) / 2,  # es_wheet_growth_mean
        (0.05 + 0.1) / 2, # es_corn_growth_mean
        (-0.05 + 0.05) / 2,  # es_others_rate_mean
        (-0.1 + 0.1) / 2,  # ty_rate_mean
        0.05,  # pc_growth_mean
        0,  # sp_growth_mean
        0.05,  # vp_growth_mean
        (-0.05 + -0.01) / 2  # mp_growth_mean
    ]
    
    # 生成随机数
    randoms = [np.random.normal(loc=mean, scale=std) for mean, std in zip(means, std_devs)]
    
    # 添加固定值
    randoms.append(-0.05)  # m1p_growth
    
    return randoms

# %%
# 打印结果
print('小麦的预期销售量增长率：', es_wheet_growth)
print('玉米的预期销售量增长率：', es_corn_growth)
print('其他农作物预期销售量相对于2023年的变化率：', es_others_rate)
print('农作物亩产量每年的变化率：', ty_rate)
print('农作物种植成本每年的增长率：', pc_growth)
print('粮食类作物销售价格每年的增长率：', sp_growth)
print('蔬菜类作物销售价格每年的增长率：', vp_growth)
print('食用菌的销售价格每年的增长率：', mp_growth)
print('羊肚菌的销售价格每年下降幅度：', m1p_growth)

# %%
# k = 0.5
# min_area_percent = 0.2
# max_plots = 4
# year = 2025
# list = [0.5, 0.2, 4, 2025]
# variables, binary_variables, actual_sales, excess_yield = create_variables(new_fields, crops)
# # 创建线性规划问题
# prob = pulp.LpProblem("Crop_Planting_Optimization", pulp.LpMaximize)
# profit = define_objective_function(variables, actual_sales, excess_yield, crops, new_fields, k)
# # 将目标函数添加到问题中
# prob += profit
# prob = add_constraints(prob, variables, binary_variables, actual_sales, 
#                        excess_yield, crops, new_fields, total_yield_2023, df2024_result, df2023_result,
#                        min_area_percent, max_plots)
# # 求解问题
# prob.solve()
# print("Status:", pulp.LpStatus[prob.status])
# # 更新new_fields
# update_new_fields(variables, new_fields)
# # 输出结果
# df_template = pd.read_excel('../excels/附件3/template.xlsx')
# output(df_template, year, new_fields)

# %%
# 添加约束条件
# 地块面积限制
for field in new_fields:
    prob += pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] for crop in crops]) <= field.field_area

# 作物种植限制
for field in new_fields:
    for crop in crops:
        if not check_crop_constraints(field, crop):
            prob += variables[(field.field_name, crop.crop_name, field.season)] == 0

# 重茬限制
for field in new_fields:
    for crop in crops:
        if not check_rotation_constraints(field, crop, df2023_result):
            prob += variables[(field.field_name, crop.crop_name, field.season)] == 0

# 实际销售量约束
for crop in crops:
    actual_yield = pulp.lpSum([
        variables[(field.field_name, crop.crop_name, field.season)] * get_yield(field, crop)
        for field in new_fields
    ])
    expected_sales = get_expected_sales(crop, total_yield_2023)
    prob += actual_sales[crop.crop_name] <= actual_yield
    prob += actual_sales[crop.crop_name] <= expected_sales

    # 超额部分约束
    prob += excess_yield[crop.crop_name] == actual_yield - expected_sales # 这里不是>=，应该是==？！
    prob += excess_yield[crop.crop_name] >= 0

# # 作物在单个地块某一季节种植面积不宜太小
# min_area_percent = 0.2
# for field in new_fields:
#     for crop in crops:
#         var = variables[(field.field_name, crop.crop_name, field.season)]
#         binary_var = binary_variables[(field.field_name, crop.crop_name, field.season)]
#         min_area = min_area_percent * field.field_area
#         prob += var >= min_area * binary_var
#         prob += var <= field.field_area * binary_var

# 作物种植不宜太分散
max_plots = 4
for crop in crops:
    for field_type in set(field.field_type for field in new_fields):
        if field_type not in ['普通大棚', '智慧大棚']:
            prob += pulp.lpSum([
                binary_variables[(field.field_name, crop.crop_name, field.season)]
                for field in new_fields if field.field_type == field_type
            ]) <= max_plots

# %%
df2023_result = pd.read_excel('../excels/附件3/2023_result.xlsx')
# 去除列名末尾的空格。很奇怪
df2023_result.columns = [column.rstrip(' ') for column in df2023_result.columns]
# print(df2023_result.columns)
df2024_result = pd.read_excel('../excels/附件3/2024_result.xlsx')
# 去除列名末尾的空格。很奇怪
df2024_result.columns = [column.rstrip(' ') for column in df2024_result.columns]
# print(df2024_result.columns)

# %%
list = [0.5, 0.2, 4, 2025]
df_last1_result = pd.read_excel('../excels/附件3/2023_result.xlsx')
df_last1_result.columns = [column.rstrip(' ') for column in df_last1_result.columns]
df_last2_result = pd.read_excel('../excels/附件3/2024_result.xlsx')
df_last2_result.columns = [column.rstrip(' ') for column in df_last2_result.columns]
optimize_planting_strategy(new_fields, crops, total_yield_2023, df2024_result, df2023_result, list)

# %% [markdown]
# ## 以下暂时作废

# %%
import pulp

# 假设 df1, df2023, df2023_result, total_yield, crops, new_fields 已经初始化

# 创建线性规划问题
prob = pulp.LpProblem("Crop_Planting_Optimization", pulp.LpMaximize)

# 创建决策变量
variables = {}
for field in new_fields:
    for crop in crops:
        var_name = f"{field.field_name}_{crop.crop_name}_{field.season}"
        variables[(field.field_name, crop.crop_name, field.season)] = pulp.LpVariable(var_name, lowBound=0)

# 输出每个变量的键值对
for varkey, varval in variables.items():
    print(varkey, varval)
# Out:
# ('A1', '黄豆', '单季') A1_黄豆_单季
# ('A1', '黑豆', '单季') A1_黑豆_单季
# ('A1', '红豆', '单季') A1_红豆_单季
# ('A1', '绿豆', '单季') A1_绿豆_单季
# ('A1', '爬豆', '单季') A1_爬豆_单季
# ('A1', '小麦', '单季') A1_小麦_单季
# ('A1', '玉米', '单季') A1_玉米_单季
# ('A1', '谷子', '单季') A1_谷子_单季
# ('A1', '高粱', '单季') A1_高粱_单季
# ('A1', '黍子', '单季') A1_黍子_单季
# ('A1', '荞麦', '单季') A1_荞麦_单季
# ('A1', '南瓜', '单季') A1_南瓜_单季
# ('A1', '红薯', '单季') A1_红薯_单季
# ('A1', '莜麦', '单季') A1_莜麦_单季
# ('A1', '大麦', '单季') A1_大麦_单季
# ('A1', '水稻', '单季') A1_水稻_单季
# ('A1', '豇豆', '单季') A1_豇豆_单季
# ('A1', '刀豆', '单季') A1_刀豆_单季
# ('A1', '芸豆', '单季') A1_芸豆_单季
# ('A1', '土豆', '单季') A1_土豆_单季
# ('A1', '西红柿', '单季') A1_西红柿_单季
# ('A1', '茄子', '单季') A1_茄子_单季
# ('A1', '菠菜 ', '单季') A1_菠菜__单季
# ('A1', '青椒', '单季') A1_青椒_单季
# ('A1', '菜花', '单季') A1_菜花_单季
# ('A1', '包菜', '单季') A1_包菜_单季
# ('A1', '油麦菜', '单季') A1_油麦菜_单季
# ('A1', '小青菜', '单季') A1_小青菜_单季
# ('A1', '黄瓜', '单季') A1_黄瓜_单季
# ('A1', '生菜 ', '单季') A1_生菜__单季
# ('A1', '辣椒', '单季') A1_辣椒_单季
# ('A1', '空心菜', '单季') A1_空心菜_单季
# ('A1', '黄心菜', '单季') A1_黄心菜_单季
# ('A1', '芹菜', '单季') A1_芹菜_单季
# ('A1', '大白菜', '单季') A1_大白菜_单季
# ('A1', '白萝卜', '单季') A1_白萝卜_单季
# ('A1', '红萝卜', '单季') A1_红萝卜_单季
# ('A1', '榆黄菇', '单季') A1_榆黄菇_单季
# ('A1', '香菇', '单季') A1_香菇_单季
# ('A1', '白灵菇', '单季') A1_白灵菇_单季
# ('A1', '羊肚菌', '单季') A1_羊肚菌_单季
# ('A2', '黄豆', '单季') A2_黄豆_单季
# ('A2', '黑豆', '单季') A2_黑豆_单季
# ('A2', '红豆', '单季') A2_红豆_单季
# ('A2', '绿豆', '单季') A2_绿豆_单季
# ('A2', '爬豆', '单季') A2_爬豆_单季
# ('A2', '小麦', '单季') A2_小麦_单季
# ('A2', '玉米', '单季') A2_玉米_单季
# ('A2', '谷子', '单季') A2_谷子_单季
# ('A2', '高粱', '单季') A2_高粱_单季
# ('A2', '黍子', '单季') A2_黍子_单季
# ('A2', '荞麦', '单季') A2_荞麦_单季
# ('A2', '南瓜', '单季') A2_南瓜_单季
# ('A2', '红薯', '单季') A2_红薯_单季
# ('A2', '莜麦', '单季') A2_莜麦_单季
# ('A2', '大麦', '单季') A2_大麦_单季
# ('A2', '水稻', '单季') A2_水稻_单季
# ('A2', '豇豆', '单季') A2_豇豆_单季
# ('A2', '刀豆', '单季') A2_刀豆_单季
# ('A2', '芸豆', '单季') A2_芸豆_单季
# ('A2', '土豆', '单季') A2_土豆_单季
# ('A2', '西红柿', '单季') A2_西红柿_单季
# ('A2', '茄子', '单季') A2_茄子_单季
# ('A2', '菠菜 ', '单季') A2_菠菜__单季
# ('A2', '青椒', '单季') A2_青椒_单季
# ('A2', '菜花', '单季') A2_菜花_单季
# ('A2', '包菜', '单季') A2_包菜_单季
# ('A2', '油麦菜', '单季') A2_油麦菜_单季
# ('A2', '小青菜', '单季') A2_小青菜_单季
# ('A2', '黄瓜', '单季') A2_黄瓜_单季
# ('A2', '生菜 ', '单季') A2_生菜__单季
# ('A2', '辣椒', '单季') A2_辣椒_单季
# ('A2', '空心菜', '单季') A2_空心菜_单季
# ('A2', '黄心菜', '单季') A2_黄心菜_单季
# ('A2', '芹菜', '单季') A2_芹菜_单季
# ('A2', '大白菜', '单季') A2_大白菜_单季
# ('A2', '白萝卜', '单季') A2_白萝卜_单季
# ('A2', '红萝卜', '单季') A2_红萝卜_单季
# ('A2', '榆黄菇', '单季') A2_榆黄菇_单季
# ('A2', '香菇', '单季') A2_香菇_单季
# ('A2', '白灵菇', '单季') A2_白灵菇_单季
# ('A2', '羊肚菌', '单季') A2_羊肚菌_单季
# ('A3', '黄豆', '单季') A3_黄豆_单季
# ('A3', '黑豆', '单季') A3_黑豆_单季
# ('A3', '红豆', '单季') A3_红豆_单季
# ('A3', '绿豆', '单季') A3_绿豆_单季
# ('A3', '爬豆', '单季') A3_爬豆_单季
# ('A3', '小麦', '单季') A3_小麦_单季
# ('A3', '玉米', '单季') A3_玉米_单季
# ('A3', '谷子', '单季') A3_谷子_单季
# ('A3', '高粱', '单季') A3_高粱_单季
# ('A3', '黍子', '单季') A3_黍子_单季
# ('A3', '荞麦', '单季') A3_荞麦_单季
# ('A3', '南瓜', '单季') A3_南瓜_单季
# ('A3', '红薯', '单季') A3_红薯_单季
# ('A3', '莜麦', '单季') A3_莜麦_单季
# ('A3', '大麦', '单季') A3_大麦_单季
# ('A3', '水稻', '单季') A3_水稻_单季
# ('A3', '豇豆', '单季') A3_豇豆_单季
# ('A3', '刀豆', '单季') A3_刀豆_单季
# ('A3', '芸豆', '单季') A3_芸豆_单季
# ('A3', '土豆', '单季') A3_土豆_单季
# ('A3', '西红柿', '单季') A3_西红柿_单季
# ('A3', '茄子', '单季') A3_茄子_单季
# ('A3', '菠菜 ', '单季') A3_菠菜__单季
# ('A3', '青椒', '单季') A3_青椒_单季
# ('A3', '菜花', '单季') A3_菜花_单季
# ('A3', '包菜', '单季') A3_包菜_单季
# ('A3', '油麦菜', '单季') A3_油麦菜_单季
# ('A3', '小青菜', '单季') A3_小青菜_单季
# ('A3', '黄瓜', '单季') A3_黄瓜_单季
# ('A3', '生菜 ', '单季') A3_生菜__单季
# ('A3', '辣椒', '单季') A3_辣椒_单季
# ('A3', '空心菜', '单季') A3_空心菜_单季
# ('A3', '黄心菜', '单季') A3_黄心菜_单季
# ('A3', '芹菜', '单季') A3_芹菜_单季
# ('A3', '大白菜', '单季') A3_大白菜_单季
# ('A3', '白萝卜', '单季') A3_白萝卜_单季
# ('A3', '红萝卜', '单季') A3_红萝卜_单季
# ('A3', '榆黄菇', '单季') A3_榆黄菇_单季
# ('A3', '香菇', '单季') A3_香菇_单季
# ('A3', '白灵菇', '单季') A3_白灵菇_单季
# ('A3', '羊肚菌', '单季') A3_羊肚菌_单季
# ('A4', '黄豆', '单季') A4_黄豆_单季
# ('A4', '黑豆', '单季') A4_黑豆_单季
# ('A4', '红豆', '单季') A4_红豆_单季
# ('A4', '绿豆', '单季') A4_绿豆_单季
# ('A4', '爬豆', '单季') A4_爬豆_单季
# ('A4', '小麦', '单季') A4_小麦_单季
# ('A4', '玉米', '单季') A4_玉米_单季
# ('A4', '谷子', '单季') A4_谷子_单季
# ('A4', '高粱', '单季') A4_高粱_单季
# ('A4', '黍子', '单季') A4_黍子_单季
# ('A4', '荞麦', '单季') A4_荞麦_单季
# ('A4', '南瓜', '单季') A4_南瓜_单季
# ('A4', '红薯', '单季') A4_红薯_单季
# ('A4', '莜麦', '单季') A4_莜麦_单季
# ('A4', '大麦', '单季') A4_大麦_单季
# ('A4', '水稻', '单季') A4_水稻_单季
# ('A4', '豇豆', '单季') A4_豇豆_单季
# ('A4', '刀豆', '单季') A4_刀豆_单季
# ('A4', '芸豆', '单季') A4_芸豆_单季
# ('A4', '土豆', '单季') A4_土豆_单季
# ('A4', '西红柿', '单季') A4_西红柿_单季
# ('A4', '茄子', '单季') A4_茄子_单季
# ('A4', '菠菜 ', '单季') A4_菠菜__单季
# ('A4', '青椒', '单季') A4_青椒_单季
# ('A4', '菜花', '单季') A4_菜花_单季
# ('A4', '包菜', '单季') A4_包菜_单季
# ('A4', '油麦菜', '单季') A4_油麦菜_单季
# ('A4', '小青菜', '单季') A4_小青菜_单季
# ('A4', '黄瓜', '单季') A4_黄瓜_单季
# ('A4', '生菜 ', '单季') A4_生菜__单季
# ('A4', '辣椒', '单季') A4_辣椒_单季
# ('A4', '空心菜', '单季') A4_空心菜_单季
# ('A4', '黄心菜', '单季') A4_黄心菜_单季
# ('A4', '芹菜', '单季') A4_芹菜_单季
# ('A4', '大白菜', '单季') A4_大白菜_单季
# ('A4', '白萝卜', '单季') A4_白萝卜_单季
# ('A4', '红萝卜', '单季') A4_红萝卜_单季
# ('A4', '榆黄菇', '单季') A4_榆黄菇_单季
# ('A4', '香菇', '单季') A4_香菇_单季
# ('A4', '白灵菇', '单季') A4_白灵菇_单季
# ('A4', '羊肚菌', '单季') A4_羊肚菌_单季
# ('A5', '黄豆', '单季') A5_黄豆_单季
# ('A5', '黑豆', '单季') A5_黑豆_单季
# ('A5', '红豆', '单季') A5_红豆_单季
# ('A5', '绿豆', '单季') A5_绿豆_单季
# ('A5', '爬豆', '单季') A5_爬豆_单季
# ('A5', '小麦', '单季') A5_小麦_单季
# ('A5', '玉米', '单季') A5_玉米_单季
# ('A5', '谷子', '单季') A5_谷子_单季
# ('A5', '高粱', '单季') A5_高粱_单季
# ('A5', '黍子', '单季') A5_黍子_单季
# ('A5', '荞麦', '单季') A5_荞麦_单季
# ('A5', '南瓜', '单季') A5_南瓜_单季
# ('A5', '红薯', '单季') A5_红薯_单季
# ('A5', '莜麦', '单季') A5_莜麦_单季
# ('A5', '大麦', '单季') A5_大麦_单季
# ('A5', '水稻', '单季') A5_水稻_单季
# ('A5', '豇豆', '单季') A5_豇豆_单季
# ('A5', '刀豆', '单季') A5_刀豆_单季
# ('A5', '芸豆', '单季') A5_芸豆_单季
# ('A5', '土豆', '单季') A5_土豆_单季
# ('A5', '西红柿', '单季') A5_西红柿_单季
# ('A5', '茄子', '单季') A5_茄子_单季
# ('A5', '菠菜 ', '单季') A5_菠菜__单季
# ('A5', '青椒', '单季') A5_青椒_单季
# ('A5', '菜花', '单季') A5_菜花_单季
# ('A5', '包菜', '单季') A5_包菜_单季
# ('A5', '油麦菜', '单季') A5_油麦菜_单季
# ('A5', '小青菜', '单季') A5_小青菜_单季
# ('A5', '黄瓜', '单季') A5_黄瓜_单季
# ('A5', '生菜 ', '单季') A5_生菜__单季
# ('A5', '辣椒', '单季') A5_辣椒_单季
# ('A5', '空心菜', '单季') A5_空心菜_单季
# ('A5', '黄心菜', '单季') A5_黄心菜_单季
# ('A5', '芹菜', '单季') A5_芹菜_单季
# ('A5', '大白菜', '单季') A5_大白菜_单季
# ('A5', '白萝卜', '单季') A5_白萝卜_单季
# ('A5', '红萝卜', '单季') A5_红萝卜_单季
# ('A5', '榆黄菇', '单季') A5_榆黄菇_单季
# ('A5', '香菇', '单季') A5_香菇_单季
# ('A5', '白灵菇', '单季') A5_白灵菇_单季
# ('A5', '羊肚菌', '单季') A5_羊肚菌_单季
# ('A6', '黄豆', '单季') A6_黄豆_单季
# ('A6', '黑豆', '单季') A6_黑豆_单季
# ('A6', '红豆', '单季') A6_红豆_单季
# ('A6', '绿豆', '单季') A6_绿豆_单季
# ('A6', '爬豆', '单季') A6_爬豆_单季
# ('A6', '小麦', '单季') A6_小麦_单季
# ('A6', '玉米', '单季') A6_玉米_单季
# ('A6', '谷子', '单季') A6_谷子_单季
# ('A6', '高粱', '单季') A6_高粱_单季
# ('A6', '黍子', '单季') A6_黍子_单季
# ('A6', '荞麦', '单季') A6_荞麦_单季
# ('A6', '南瓜', '单季') A6_南瓜_单季
# ('A6', '红薯', '单季') A6_红薯_单季
# ('A6', '莜麦', '单季') A6_莜麦_单季
# ('A6', '大麦', '单季') A6_大麦_单季
# ('A6', '水稻', '单季') A6_水稻_单季
# ('A6', '豇豆', '单季') A6_豇豆_单季
# ('A6', '刀豆', '单季') A6_刀豆_单季
# ('A6', '芸豆', '单季') A6_芸豆_单季
# ('A6', '土豆', '单季') A6_土豆_单季
# ('A6', '西红柿', '单季') A6_西红柿_单季
# ('A6', '茄子', '单季') A6_茄子_单季
# ('A6', '菠菜 ', '单季') A6_菠菜__单季
# ('A6', '青椒', '单季') A6_青椒_单季
# ('A6', '菜花', '单季') A6_菜花_单季
# ('A6', '包菜', '单季') A6_包菜_单季
# ('A6', '油麦菜', '单季') A6_油麦菜_单季
# ('A6', '小青菜', '单季') A6_小青菜_单季
# ('A6', '黄瓜', '单季') A6_黄瓜_单季
# ('A6', '生菜 ', '单季') A6_生菜__单季
# ('A6', '辣椒', '单季') A6_辣椒_单季
# ('A6', '空心菜', '单季') A6_空心菜_单季
# ('A6', '黄心菜', '单季') A6_黄心菜_单季
# ('A6', '芹菜', '单季') A6_芹菜_单季
# ('A6', '大白菜', '单季') A6_大白菜_单季
# ('A6', '白萝卜', '单季') A6_白萝卜_单季
# ('A6', '红萝卜', '单季') A6_红萝卜_单季
# ('A6', '榆黄菇', '单季') A6_榆黄菇_单季
# ('A6', '香菇', '单季') A6_香菇_单季
# ('A6', '白灵菇', '单季') A6_白灵菇_单季
# ('A6', '羊肚菌', '单季') A6_羊肚菌_单季
# ('B1', '黄豆', '单季') B1_黄豆_单季
# ('B1', '黑豆', '单季') B1_黑豆_单季
# ('B1', '红豆', '单季') B1_红豆_单季
# ('B1', '绿豆', '单季') B1_绿豆_单季
# ('B1', '爬豆', '单季') B1_爬豆_单季
# ('B1', '小麦', '单季') B1_小麦_单季
# ('B1', '玉米', '单季') B1_玉米_单季
# ('B1', '谷子', '单季') B1_谷子_单季
# ('B1', '高粱', '单季') B1_高粱_单季
# ('B1', '黍子', '单季') B1_黍子_单季
# ('B1', '荞麦', '单季') B1_荞麦_单季
# ('B1', '南瓜', '单季') B1_南瓜_单季
# ('B1', '红薯', '单季') B1_红薯_单季
# ('B1', '莜麦', '单季') B1_莜麦_单季
# ('B1', '大麦', '单季') B1_大麦_单季
# ('B1', '水稻', '单季') B1_水稻_单季
# ('B1', '豇豆', '单季') B1_豇豆_单季
# ('B1', '刀豆', '单季') B1_刀豆_单季
# ('B1', '芸豆', '单季') B1_芸豆_单季
# ('B1', '土豆', '单季') B1_土豆_单季
# ('B1', '西红柿', '单季') B1_西红柿_单季
# ('B1', '茄子', '单季') B1_茄子_单季
# ('B1', '菠菜 ', '单季') B1_菠菜__单季
# ('B1', '青椒', '单季') B1_青椒_单季
# ('B1', '菜花', '单季') B1_菜花_单季
# ('B1', '包菜', '单季') B1_包菜_单季
# ('B1', '油麦菜', '单季') B1_油麦菜_单季
# ('B1', '小青菜', '单季') B1_小青菜_单季
# ('B1', '黄瓜', '单季') B1_黄瓜_单季
# ('B1', '生菜 ', '单季') B1_生菜__单季
# ('B1', '辣椒', '单季') B1_辣椒_单季
# ('B1', '空心菜', '单季') B1_空心菜_单季
# ('B1', '黄心菜', '单季') B1_黄心菜_单季
# ('B1', '芹菜', '单季') B1_芹菜_单季
# ('B1', '大白菜', '单季') B1_大白菜_单季
# ('B1', '白萝卜', '单季') B1_白萝卜_单季
# ('B1', '红萝卜', '单季') B1_红萝卜_单季
# ('B1', '榆黄菇', '单季') B1_榆黄菇_单季
# ('B1', '香菇', '单季') B1_香菇_单季
# ('B1', '白灵菇', '单季') B1_白灵菇_单季
# ('B1', '羊肚菌', '单季') B1_羊肚菌_单季
# ('B2', '黄豆', '单季') B2_黄豆_单季
# ('B2', '黑豆', '单季') B2_黑豆_单季
# ('B2', '红豆', '单季') B2_红豆_单季
# ('B2', '绿豆', '单季') B2_绿豆_单季
# ('B2', '爬豆', '单季') B2_爬豆_单季
# ('B2', '小麦', '单季') B2_小麦_单季
# ('B2', '玉米', '单季') B2_玉米_单季
# ('B2', '谷子', '单季') B2_谷子_单季
# ('B2', '高粱', '单季') B2_高粱_单季
# ('B2', '黍子', '单季') B2_黍子_单季
# ('B2', '荞麦', '单季') B2_荞麦_单季
# ('B2', '南瓜', '单季') B2_南瓜_单季
# ('B2', '红薯', '单季') B2_红薯_单季
# ('B2', '莜麦', '单季') B2_莜麦_单季
# ('B2', '大麦', '单季') B2_大麦_单季
# ('B2', '水稻', '单季') B2_水稻_单季
# ('B2', '豇豆', '单季') B2_豇豆_单季
# ('B2', '刀豆', '单季') B2_刀豆_单季
# ('B2', '芸豆', '单季') B2_芸豆_单季
# ('B2', '土豆', '单季') B2_土豆_单季
# ('B2', '西红柿', '单季') B2_西红柿_单季
# ('B2', '茄子', '单季') B2_茄子_单季
# ('B2', '菠菜 ', '单季') B2_菠菜__单季
# ('B2', '青椒', '单季') B2_青椒_单季
# ('B2', '菜花', '单季') B2_菜花_单季
# ('B2', '包菜', '单季') B2_包菜_单季
# ('B2', '油麦菜', '单季') B2_油麦菜_单季
# ('B2', '小青菜', '单季') B2_小青菜_单季
# ('B2', '黄瓜', '单季') B2_黄瓜_单季
# ('B2', '生菜 ', '单季') B2_生菜__单季
# ('B2', '辣椒', '单季') B2_辣椒_单季
# ('B2', '空心菜', '单季') B2_空心菜_单季
# ('B2', '黄心菜', '单季') B2_黄心菜_单季
# ('B2', '芹菜', '单季') B2_芹菜_单季
# ('B2', '大白菜', '单季') B2_大白菜_单季
# ('B2', '白萝卜', '单季') B2_白萝卜_单季
# ('B2', '红萝卜', '单季') B2_红萝卜_单季
# ('B2', '榆黄菇', '单季') B2_榆黄菇_单季
# ('B2', '香菇', '单季') B2_香菇_单季
# ('B2', '白灵菇', '单季') B2_白灵菇_单季
# ('B2', '羊肚菌', '单季') B2_羊肚菌_单季
# ('B3', '黄豆', '单季') B3_黄豆_单季
# ('B3', '黑豆', '单季') B3_黑豆_单季
# ('B3', '红豆', '单季') B3_红豆_单季
# ('B3', '绿豆', '单季') B3_绿豆_单季
# ('B3', '爬豆', '单季') B3_爬豆_单季
# ('B3', '小麦', '单季') B3_小麦_单季
# ('B3', '玉米', '单季') B3_玉米_单季
# ('B3', '谷子', '单季') B3_谷子_单季
# ('B3', '高粱', '单季') B3_高粱_单季
# ('B3', '黍子', '单季') B3_黍子_单季
# ('B3', '荞麦', '单季') B3_荞麦_单季
# ('B3', '南瓜', '单季') B3_南瓜_单季
# ('B3', '红薯', '单季') B3_红薯_单季
# ('B3', '莜麦', '单季') B3_莜麦_单季
# ('B3', '大麦', '单季') B3_大麦_单季
# ('B3', '水稻', '单季') B3_水稻_单季
# ('B3', '豇豆', '单季') B3_豇豆_单季
# ('B3', '刀豆', '单季') B3_刀豆_单季
# ('B3', '芸豆', '单季') B3_芸豆_单季
# ('B3', '土豆', '单季') B3_土豆_单季
# ('B3', '西红柿', '单季') B3_西红柿_单季
# ('B3', '茄子', '单季') B3_茄子_单季
# ('B3', '菠菜 ', '单季') B3_菠菜__单季
# ('B3', '青椒', '单季') B3_青椒_单季
# ('B3', '菜花', '单季') B3_菜花_单季
# ('B3', '包菜', '单季') B3_包菜_单季
# ('B3', '油麦菜', '单季') B3_油麦菜_单季
# ('B3', '小青菜', '单季') B3_小青菜_单季
# ('B3', '黄瓜', '单季') B3_黄瓜_单季
# ('B3', '生菜 ', '单季') B3_生菜__单季
# ('B3', '辣椒', '单季') B3_辣椒_单季
# ('B3', '空心菜', '单季') B3_空心菜_单季
# ('B3', '黄心菜', '单季') B3_黄心菜_单季
# ('B3', '芹菜', '单季') B3_芹菜_单季
# ('B3', '大白菜', '单季') B3_大白菜_单季
# ('B3', '白萝卜', '单季') B3_白萝卜_单季
# ('B3', '红萝卜', '单季') B3_红萝卜_单季
# ('B3', '榆黄菇', '单季') B3_榆黄菇_单季
# ('B3', '香菇', '单季') B3_香菇_单季
# ('B3', '白灵菇', '单季') B3_白灵菇_单季
# ('B3', '羊肚菌', '单季') B3_羊肚菌_单季
# ('B4', '黄豆', '单季') B4_黄豆_单季
# ('B4', '黑豆', '单季') B4_黑豆_单季
# ('B4', '红豆', '单季') B4_红豆_单季
# ('B4', '绿豆', '单季') B4_绿豆_单季
# ('B4', '爬豆', '单季') B4_爬豆_单季
# ('B4', '小麦', '单季') B4_小麦_单季
# ('B4', '玉米', '单季') B4_玉米_单季
# ('B4', '谷子', '单季') B4_谷子_单季
# ('B4', '高粱', '单季') B4_高粱_单季
# ('B4', '黍子', '单季') B4_黍子_单季
# ('B4', '荞麦', '单季') B4_荞麦_单季
# ('B4', '南瓜', '单季') B4_南瓜_单季
# ('B4', '红薯', '单季') B4_红薯_单季
# ('B4', '莜麦', '单季') B4_莜麦_单季
# ('B4', '大麦', '单季') B4_大麦_单季
# ('B4', '水稻', '单季') B4_水稻_单季
# ('B4', '豇豆', '单季') B4_豇豆_单季
# ('B4', '刀豆', '单季') B4_刀豆_单季
# ('B4', '芸豆', '单季') B4_芸豆_单季
# ('B4', '土豆', '单季') B4_土豆_单季
# ('B4', '西红柿', '单季') B4_西红柿_单季
# ('B4', '茄子', '单季') B4_茄子_单季
# ('B4', '菠菜 ', '单季') B4_菠菜__单季
# ('B4', '青椒', '单季') B4_青椒_单季
# ('B4', '菜花', '单季') B4_菜花_单季
# ('B4', '包菜', '单季') B4_包菜_单季
# ('B4', '油麦菜', '单季') B4_油麦菜_单季
# ('B4', '小青菜', '单季') B4_小青菜_单季
# ('B4', '黄瓜', '单季') B4_黄瓜_单季
# ('B4', '生菜 ', '单季') B4_生菜__单季
# ('B4', '辣椒', '单季') B4_辣椒_单季
# ('B4', '空心菜', '单季') B4_空心菜_单季
# ('B4', '黄心菜', '单季') B4_黄心菜_单季
# ('B4', '芹菜', '单季') B4_芹菜_单季
# ('B4', '大白菜', '单季') B4_大白菜_单季
# ('B4', '白萝卜', '单季') B4_白萝卜_单季
# ('B4', '红萝卜', '单季') B4_红萝卜_单季
# ('B4', '榆黄菇', '单季') B4_榆黄菇_单季
# ('B4', '香菇', '单季') B4_香菇_单季
# ('B4', '白灵菇', '单季') B4_白灵菇_单季
# ('B4', '羊肚菌', '单季') B4_羊肚菌_单季
# ('B5', '黄豆', '单季') B5_黄豆_单季
# ('B5', '黑豆', '单季') B5_黑豆_单季
# ('B5', '红豆', '单季') B5_红豆_单季
# ('B5', '绿豆', '单季') B5_绿豆_单季
# ('B5', '爬豆', '单季') B5_爬豆_单季
# ('B5', '小麦', '单季') B5_小麦_单季
# ('B5', '玉米', '单季') B5_玉米_单季
# ('B5', '谷子', '单季') B5_谷子_单季
# ('B5', '高粱', '单季') B5_高粱_单季
# ('B5', '黍子', '单季') B5_黍子_单季
# ('B5', '荞麦', '单季') B5_荞麦_单季
# ('B5', '南瓜', '单季') B5_南瓜_单季
# ('B5', '红薯', '单季') B5_红薯_单季
# ('B5', '莜麦', '单季') B5_莜麦_单季
# ('B5', '大麦', '单季') B5_大麦_单季
# ('B5', '水稻', '单季') B5_水稻_单季
# ('B5', '豇豆', '单季') B5_豇豆_单季
# ('B5', '刀豆', '单季') B5_刀豆_单季
# ('B5', '芸豆', '单季') B5_芸豆_单季
# ('B5', '土豆', '单季') B5_土豆_单季
# ('B5', '西红柿', '单季') B5_西红柿_单季
# ('B5', '茄子', '单季') B5_茄子_单季
# ('B5', '菠菜 ', '单季') B5_菠菜__单季
# ('B5', '青椒', '单季') B5_青椒_单季
# ('B5', '菜花', '单季') B5_菜花_单季
# ('B5', '包菜', '单季') B5_包菜_单季
# ('B5', '油麦菜', '单季') B5_油麦菜_单季
# ('B5', '小青菜', '单季') B5_小青菜_单季
# ('B5', '黄瓜', '单季') B5_黄瓜_单季
# ('B5', '生菜 ', '单季') B5_生菜__单季
# ('B5', '辣椒', '单季') B5_辣椒_单季
# ('B5', '空心菜', '单季') B5_空心菜_单季
# ('B5', '黄心菜', '单季') B5_黄心菜_单季
# ('B5', '芹菜', '单季') B5_芹菜_单季
# ('B5', '大白菜', '单季') B5_大白菜_单季
# ('B5', '白萝卜', '单季') B5_白萝卜_单季
# ('B5', '红萝卜', '单季') B5_红萝卜_单季
# ('B5', '榆黄菇', '单季') B5_榆黄菇_单季
# ('B5', '香菇', '单季') B5_香菇_单季
# ('B5', '白灵菇', '单季') B5_白灵菇_单季
# ('B5', '羊肚菌', '单季') B5_羊肚菌_单季
# ('B6', '黄豆', '单季') B6_黄豆_单季
# ('B6', '黑豆', '单季') B6_黑豆_单季
# ('B6', '红豆', '单季') B6_红豆_单季
# ('B6', '绿豆', '单季') B6_绿豆_单季
# ('B6', '爬豆', '单季') B6_爬豆_单季
# ('B6', '小麦', '单季') B6_小麦_单季
# ('B6', '玉米', '单季') B6_玉米_单季
# ('B6', '谷子', '单季') B6_谷子_单季
# ('B6', '高粱', '单季') B6_高粱_单季
# ('B6', '黍子', '单季') B6_黍子_单季
# ('B6', '荞麦', '单季') B6_荞麦_单季
# ('B6', '南瓜', '单季') B6_南瓜_单季
# ('B6', '红薯', '单季') B6_红薯_单季
# ('B6', '莜麦', '单季') B6_莜麦_单季
# ('B6', '大麦', '单季') B6_大麦_单季
# ('B6', '水稻', '单季') B6_水稻_单季
# ('B6', '豇豆', '单季') B6_豇豆_单季
# ('B6', '刀豆', '单季') B6_刀豆_单季
# ('B6', '芸豆', '单季') B6_芸豆_单季
# ('B6', '土豆', '单季') B6_土豆_单季
# ('B6', '西红柿', '单季') B6_西红柿_单季
# ('B6', '茄子', '单季') B6_茄子_单季
# ('B6', '菠菜 ', '单季') B6_菠菜__单季
# ('B6', '青椒', '单季') B6_青椒_单季
# ('B6', '菜花', '单季') B6_菜花_单季
# ('B6', '包菜', '单季') B6_包菜_单季
# ('B6', '油麦菜', '单季') B6_油麦菜_单季
# ('B6', '小青菜', '单季') B6_小青菜_单季
# ('B6', '黄瓜', '单季') B6_黄瓜_单季
# ('B6', '生菜 ', '单季') B6_生菜__单季
# ('B6', '辣椒', '单季') B6_辣椒_单季
# ('B6', '空心菜', '单季') B6_空心菜_单季
# ('B6', '黄心菜', '单季') B6_黄心菜_单季
# ('B6', '芹菜', '单季') B6_芹菜_单季
# ('B6', '大白菜', '单季') B6_大白菜_单季
# ('B6', '白萝卜', '单季') B6_白萝卜_单季
# ('B6', '红萝卜', '单季') B6_红萝卜_单季
# ('B6', '榆黄菇', '单季') B6_榆黄菇_单季
# ('B6', '香菇', '单季') B6_香菇_单季
# ('B6', '白灵菇', '单季') B6_白灵菇_单季
# ('B6', '羊肚菌', '单季') B6_羊肚菌_单季
# ('B7', '黄豆', '单季') B7_黄豆_单季
# ('B7', '黑豆', '单季') B7_黑豆_单季
# ('B7', '红豆', '单季') B7_红豆_单季
# ('B7', '绿豆', '单季') B7_绿豆_单季
# ('B7', '爬豆', '单季') B7_爬豆_单季
# ('B7', '小麦', '单季') B7_小麦_单季
# ('B7', '玉米', '单季') B7_玉米_单季
# ('B7', '谷子', '单季') B7_谷子_单季
# ('B7', '高粱', '单季') B7_高粱_单季
# ('B7', '黍子', '单季') B7_黍子_单季
# ('B7', '荞麦', '单季') B7_荞麦_单季
# ('B7', '南瓜', '单季') B7_南瓜_单季
# ('B7', '红薯', '单季') B7_红薯_单季
# ('B7', '莜麦', '单季') B7_莜麦_单季
# ('B7', '大麦', '单季') B7_大麦_单季
# ('B7', '水稻', '单季') B7_水稻_单季
# ('B7', '豇豆', '单季') B7_豇豆_单季
# ('B7', '刀豆', '单季') B7_刀豆_单季
# ('B7', '芸豆', '单季') B7_芸豆_单季
# ('B7', '土豆', '单季') B7_土豆_单季
# ('B7', '西红柿', '单季') B7_西红柿_单季
# ('B7', '茄子', '单季') B7_茄子_单季
# ('B7', '菠菜 ', '单季') B7_菠菜__单季
# ('B7', '青椒', '单季') B7_青椒_单季
# ('B7', '菜花', '单季') B7_菜花_单季
# ('B7', '包菜', '单季') B7_包菜_单季
# ('B7', '油麦菜', '单季') B7_油麦菜_单季
# ('B7', '小青菜', '单季') B7_小青菜_单季
# ('B7', '黄瓜', '单季') B7_黄瓜_单季
# ('B7', '生菜 ', '单季') B7_生菜__单季
# ('B7', '辣椒', '单季') B7_辣椒_单季
# ('B7', '空心菜', '单季') B7_空心菜_单季
# ('B7', '黄心菜', '单季') B7_黄心菜_单季
# ('B7', '芹菜', '单季') B7_芹菜_单季
# ('B7', '大白菜', '单季') B7_大白菜_单季
# ('B7', '白萝卜', '单季') B7_白萝卜_单季
# ('B7', '红萝卜', '单季') B7_红萝卜_单季
# ('B7', '榆黄菇', '单季') B7_榆黄菇_单季
# ('B7', '香菇', '单季') B7_香菇_单季
# ('B7', '白灵菇', '单季') B7_白灵菇_单季
# ('B7', '羊肚菌', '单季') B7_羊肚菌_单季
# ('B8', '黄豆', '单季') B8_黄豆_单季
# ('B8', '黑豆', '单季') B8_黑豆_单季
# ('B8', '红豆', '单季') B8_红豆_单季
# ('B8', '绿豆', '单季') B8_绿豆_单季
# ('B8', '爬豆', '单季') B8_爬豆_单季
# ('B8', '小麦', '单季') B8_小麦_单季
# ('B8', '玉米', '单季') B8_玉米_单季
# ('B8', '谷子', '单季') B8_谷子_单季
# ('B8', '高粱', '单季') B8_高粱_单季
# ('B8', '黍子', '单季') B8_黍子_单季
# ('B8', '荞麦', '单季') B8_荞麦_单季
# ('B8', '南瓜', '单季') B8_南瓜_单季
# ('B8', '红薯', '单季') B8_红薯_单季
# ('B8', '莜麦', '单季') B8_莜麦_单季
# ('B8', '大麦', '单季') B8_大麦_单季
# ('B8', '水稻', '单季') B8_水稻_单季
# ('B8', '豇豆', '单季') B8_豇豆_单季
# ('B8', '刀豆', '单季') B8_刀豆_单季
# ('B8', '芸豆', '单季') B8_芸豆_单季
# ('B8', '土豆', '单季') B8_土豆_单季
# ('B8', '西红柿', '单季') B8_西红柿_单季
# ('B8', '茄子', '单季') B8_茄子_单季
# ('B8', '菠菜 ', '单季') B8_菠菜__单季
# ('B8', '青椒', '单季') B8_青椒_单季
# ('B8', '菜花', '单季') B8_菜花_单季
# ('B8', '包菜', '单季') B8_包菜_单季
# ('B8', '油麦菜', '单季') B8_油麦菜_单季
# ('B8', '小青菜', '单季') B8_小青菜_单季
# ('B8', '黄瓜', '单季') B8_黄瓜_单季
# ('B8', '生菜 ', '单季') B8_生菜__单季
# ('B8', '辣椒', '单季') B8_辣椒_单季
# ('B8', '空心菜', '单季') B8_空心菜_单季
# ('B8', '黄心菜', '单季') B8_黄心菜_单季
# ('B8', '芹菜', '单季') B8_芹菜_单季
# ('B8', '大白菜', '单季') B8_大白菜_单季
# ('B8', '白萝卜', '单季') B8_白萝卜_单季
# ('B8', '红萝卜', '单季') B8_红萝卜_单季
# ('B8', '榆黄菇', '单季') B8_榆黄菇_单季
# ('B8', '香菇', '单季') B8_香菇_单季
# ('B8', '白灵菇', '单季') B8_白灵菇_单季
# ('B8', '羊肚菌', '单季') B8_羊肚菌_单季
# ('B9', '黄豆', '单季') B9_黄豆_单季
# ('B9', '黑豆', '单季') B9_黑豆_单季
# ('B9', '红豆', '单季') B9_红豆_单季
# ('B9', '绿豆', '单季') B9_绿豆_单季
# ('B9', '爬豆', '单季') B9_爬豆_单季
# ('B9', '小麦', '单季') B9_小麦_单季
# ('B9', '玉米', '单季') B9_玉米_单季
# ('B9', '谷子', '单季') B9_谷子_单季
# ('B9', '高粱', '单季') B9_高粱_单季
# ('B9', '黍子', '单季') B9_黍子_单季
# ('B9', '荞麦', '单季') B9_荞麦_单季
# ('B9', '南瓜', '单季') B9_南瓜_单季
# ('B9', '红薯', '单季') B9_红薯_单季
# ('B9', '莜麦', '单季') B9_莜麦_单季
# ('B9', '大麦', '单季') B9_大麦_单季
# ('B9', '水稻', '单季') B9_水稻_单季
# ('B9', '豇豆', '单季') B9_豇豆_单季
# ('B9', '刀豆', '单季') B9_刀豆_单季
# ('B9', '芸豆', '单季') B9_芸豆_单季
# ('B9', '土豆', '单季') B9_土豆_单季
# ('B9', '西红柿', '单季') B9_西红柿_单季
# ('B9', '茄子', '单季') B9_茄子_单季
# ('B9', '菠菜 ', '单季') B9_菠菜__单季
# ('B9', '青椒', '单季') B9_青椒_单季
# ('B9', '菜花', '单季') B9_菜花_单季
# ('B9', '包菜', '单季') B9_包菜_单季
# ('B9', '油麦菜', '单季') B9_油麦菜_单季
# ('B9', '小青菜', '单季') B9_小青菜_单季
# ('B9', '黄瓜', '单季') B9_黄瓜_单季
# ('B9', '生菜 ', '单季') B9_生菜__单季
# ('B9', '辣椒', '单季') B9_辣椒_单季
# ('B9', '空心菜', '单季') B9_空心菜_单季
# ('B9', '黄心菜', '单季') B9_黄心菜_单季
# ('B9', '芹菜', '单季') B9_芹菜_单季
# ('B9', '大白菜', '单季') B9_大白菜_单季
# ('B9', '白萝卜', '单季') B9_白萝卜_单季
# ('B9', '红萝卜', '单季') B9_红萝卜_单季
# ('B9', '榆黄菇', '单季') B9_榆黄菇_单季
# ('B9', '香菇', '单季') B9_香菇_单季
# ('B9', '白灵菇', '单季') B9_白灵菇_单季
# ('B9', '羊肚菌', '单季') B9_羊肚菌_单季
# ('B10', '黄豆', '单季') B10_黄豆_单季
# ('B10', '黑豆', '单季') B10_黑豆_单季
# ('B10', '红豆', '单季') B10_红豆_单季
# ('B10', '绿豆', '单季') B10_绿豆_单季
# ('B10', '爬豆', '单季') B10_爬豆_单季
# ('B10', '小麦', '单季') B10_小麦_单季
# ('B10', '玉米', '单季') B10_玉米_单季
# ('B10', '谷子', '单季') B10_谷子_单季
# ('B10', '高粱', '单季') B10_高粱_单季
# ('B10', '黍子', '单季') B10_黍子_单季
# ('B10', '荞麦', '单季') B10_荞麦_单季
# ('B10', '南瓜', '单季') B10_南瓜_单季
# ('B10', '红薯', '单季') B10_红薯_单季
# ('B10', '莜麦', '单季') B10_莜麦_单季
# ('B10', '大麦', '单季') B10_大麦_单季
# ('B10', '水稻', '单季') B10_水稻_单季
# ('B10', '豇豆', '单季') B10_豇豆_单季
# ('B10', '刀豆', '单季') B10_刀豆_单季
# ('B10', '芸豆', '单季') B10_芸豆_单季
# ('B10', '土豆', '单季') B10_土豆_单季
# ('B10', '西红柿', '单季') B10_西红柿_单季
# ('B10', '茄子', '单季') B10_茄子_单季
# ('B10', '菠菜 ', '单季') B10_菠菜__单季
# ('B10', '青椒', '单季') B10_青椒_单季
# ('B10', '菜花', '单季') B10_菜花_单季
# ('B10', '包菜', '单季') B10_包菜_单季
# ('B10', '油麦菜', '单季') B10_油麦菜_单季
# ('B10', '小青菜', '单季') B10_小青菜_单季
# ('B10', '黄瓜', '单季') B10_黄瓜_单季
# ('B10', '生菜 ', '单季') B10_生菜__单季
# ('B10', '辣椒', '单季') B10_辣椒_单季
# ('B10', '空心菜', '单季') B10_空心菜_单季
# ('B10', '黄心菜', '单季') B10_黄心菜_单季
# ('B10', '芹菜', '单季') B10_芹菜_单季
# ('B10', '大白菜', '单季') B10_大白菜_单季
# ('B10', '白萝卜', '单季') B10_白萝卜_单季
# ('B10', '红萝卜', '单季') B10_红萝卜_单季
# ('B10', '榆黄菇', '单季') B10_榆黄菇_单季
# ('B10', '香菇', '单季') B10_香菇_单季
# ('B10', '白灵菇', '单季') B10_白灵菇_单季
# ('B10', '羊肚菌', '单季') B10_羊肚菌_单季
# ('B11', '黄豆', '单季') B11_黄豆_单季
# ('B11', '黑豆', '单季') B11_黑豆_单季
# ('B11', '红豆', '单季') B11_红豆_单季
# ('B11', '绿豆', '单季') B11_绿豆_单季
# ('B11', '爬豆', '单季') B11_爬豆_单季
# ('B11', '小麦', '单季') B11_小麦_单季
# ('B11', '玉米', '单季') B11_玉米_单季
# ('B11', '谷子', '单季') B11_谷子_单季
# ('B11', '高粱', '单季') B11_高粱_单季
# ('B11', '黍子', '单季') B11_黍子_单季
# ('B11', '荞麦', '单季') B11_荞麦_单季
# ('B11', '南瓜', '单季') B11_南瓜_单季
# ('B11', '红薯', '单季') B11_红薯_单季
# ('B11', '莜麦', '单季') B11_莜麦_单季
# ('B11', '大麦', '单季') B11_大麦_单季
# ('B11', '水稻', '单季') B11_水稻_单季
# ('B11', '豇豆', '单季') B11_豇豆_单季
# ('B11', '刀豆', '单季') B11_刀豆_单季
# ('B11', '芸豆', '单季') B11_芸豆_单季
# ('B11', '土豆', '单季') B11_土豆_单季
# ('B11', '西红柿', '单季') B11_西红柿_单季
# ('B11', '茄子', '单季') B11_茄子_单季
# ('B11', '菠菜 ', '单季') B11_菠菜__单季
# ('B11', '青椒', '单季') B11_青椒_单季
# ('B11', '菜花', '单季') B11_菜花_单季
# ('B11', '包菜', '单季') B11_包菜_单季
# ('B11', '油麦菜', '单季') B11_油麦菜_单季
# ('B11', '小青菜', '单季') B11_小青菜_单季
# ('B11', '黄瓜', '单季') B11_黄瓜_单季
# ('B11', '生菜 ', '单季') B11_生菜__单季
# ('B11', '辣椒', '单季') B11_辣椒_单季
# ('B11', '空心菜', '单季') B11_空心菜_单季
# ('B11', '黄心菜', '单季') B11_黄心菜_单季
# ('B11', '芹菜', '单季') B11_芹菜_单季
# ('B11', '大白菜', '单季') B11_大白菜_单季
# ('B11', '白萝卜', '单季') B11_白萝卜_单季
# ('B11', '红萝卜', '单季') B11_红萝卜_单季
# ('B11', '榆黄菇', '单季') B11_榆黄菇_单季
# ('B11', '香菇', '单季') B11_香菇_单季
# ('B11', '白灵菇', '单季') B11_白灵菇_单季
# ('B11', '羊肚菌', '单季') B11_羊肚菌_单季
# ('B12', '黄豆', '单季') B12_黄豆_单季
# ('B12', '黑豆', '单季') B12_黑豆_单季
# ('B12', '红豆', '单季') B12_红豆_单季
# ('B12', '绿豆', '单季') B12_绿豆_单季
# ('B12', '爬豆', '单季') B12_爬豆_单季
# ('B12', '小麦', '单季') B12_小麦_单季
# ('B12', '玉米', '单季') B12_玉米_单季
# ('B12', '谷子', '单季') B12_谷子_单季
# ('B12', '高粱', '单季') B12_高粱_单季
# ('B12', '黍子', '单季') B12_黍子_单季
# ('B12', '荞麦', '单季') B12_荞麦_单季
# ('B12', '南瓜', '单季') B12_南瓜_单季
# ('B12', '红薯', '单季') B12_红薯_单季
# ('B12', '莜麦', '单季') B12_莜麦_单季
# ('B12', '大麦', '单季') B12_大麦_单季
# ('B12', '水稻', '单季') B12_水稻_单季
# ('B12', '豇豆', '单季') B12_豇豆_单季
# ('B12', '刀豆', '单季') B12_刀豆_单季
# ('B12', '芸豆', '单季') B12_芸豆_单季
# ('B12', '土豆', '单季') B12_土豆_单季
# ('B12', '西红柿', '单季') B12_西红柿_单季
# ('B12', '茄子', '单季') B12_茄子_单季
# ('B12', '菠菜 ', '单季') B12_菠菜__单季
# ('B12', '青椒', '单季') B12_青椒_单季
# ('B12', '菜花', '单季') B12_菜花_单季
# ('B12', '包菜', '单季') B12_包菜_单季
# ('B12', '油麦菜', '单季') B12_油麦菜_单季
# ('B12', '小青菜', '单季') B12_小青菜_单季
# ('B12', '黄瓜', '单季') B12_黄瓜_单季
# ('B12', '生菜 ', '单季') B12_生菜__单季
# ('B12', '辣椒', '单季') B12_辣椒_单季
# ('B12', '空心菜', '单季') B12_空心菜_单季
# ('B12', '黄心菜', '单季') B12_黄心菜_单季
# ('B12', '芹菜', '单季') B12_芹菜_单季
# ('B12', '大白菜', '单季') B12_大白菜_单季
# ('B12', '白萝卜', '单季') B12_白萝卜_单季
# ('B12', '红萝卜', '单季') B12_红萝卜_单季
# ('B12', '榆黄菇', '单季') B12_榆黄菇_单季
# ('B12', '香菇', '单季') B12_香菇_单季
# ('B12', '白灵菇', '单季') B12_白灵菇_单季
# ('B12', '羊肚菌', '单季') B12_羊肚菌_单季
# ('B13', '黄豆', '单季') B13_黄豆_单季
# ('B13', '黑豆', '单季') B13_黑豆_单季
# ('B13', '红豆', '单季') B13_红豆_单季
# ('B13', '绿豆', '单季') B13_绿豆_单季
# ('B13', '爬豆', '单季') B13_爬豆_单季
# ('B13', '小麦', '单季') B13_小麦_单季
# ('B13', '玉米', '单季') B13_玉米_单季
# ('B13', '谷子', '单季') B13_谷子_单季
# ('B13', '高粱', '单季') B13_高粱_单季
# ('B13', '黍子', '单季') B13_黍子_单季
# ('B13', '荞麦', '单季') B13_荞麦_单季
# ('B13', '南瓜', '单季') B13_南瓜_单季
# ('B13', '红薯', '单季') B13_红薯_单季
# ('B13', '莜麦', '单季') B13_莜麦_单季
# ('B13', '大麦', '单季') B13_大麦_单季
# ('B13', '水稻', '单季') B13_水稻_单季
# ('B13', '豇豆', '单季') B13_豇豆_单季
# ('B13', '刀豆', '单季') B13_刀豆_单季
# ('B13', '芸豆', '单季') B13_芸豆_单季
# ('B13', '土豆', '单季') B13_土豆_单季
# ('B13', '西红柿', '单季') B13_西红柿_单季
# ('B13', '茄子', '单季') B13_茄子_单季
# ('B13', '菠菜 ', '单季') B13_菠菜__单季
# ('B13', '青椒', '单季') B13_青椒_单季
# ('B13', '菜花', '单季') B13_菜花_单季
# ('B13', '包菜', '单季') B13_包菜_单季
# ('B13', '油麦菜', '单季') B13_油麦菜_单季
# ('B13', '小青菜', '单季') B13_小青菜_单季
# ('B13', '黄瓜', '单季') B13_黄瓜_单季
# ('B13', '生菜 ', '单季') B13_生菜__单季
# ('B13', '辣椒', '单季') B13_辣椒_单季
# ('B13', '空心菜', '单季') B13_空心菜_单季
# ('B13', '黄心菜', '单季') B13_黄心菜_单季
# ('B13', '芹菜', '单季') B13_芹菜_单季
# ('B13', '大白菜', '单季') B13_大白菜_单季
# ('B13', '白萝卜', '单季') B13_白萝卜_单季
# ('B13', '红萝卜', '单季') B13_红萝卜_单季
# ('B13', '榆黄菇', '单季') B13_榆黄菇_单季
# ('B13', '香菇', '单季') B13_香菇_单季
# ('B13', '白灵菇', '单季') B13_白灵菇_单季
# ('B13', '羊肚菌', '单季') B13_羊肚菌_单季
# ('B14', '黄豆', '单季') B14_黄豆_单季
# ('B14', '黑豆', '单季') B14_黑豆_单季
# ('B14', '红豆', '单季') B14_红豆_单季
# ('B14', '绿豆', '单季') B14_绿豆_单季
# ('B14', '爬豆', '单季') B14_爬豆_单季
# ('B14', '小麦', '单季') B14_小麦_单季
# ('B14', '玉米', '单季') B14_玉米_单季
# ('B14', '谷子', '单季') B14_谷子_单季
# ('B14', '高粱', '单季') B14_高粱_单季
# ('B14', '黍子', '单季') B14_黍子_单季
# ('B14', '荞麦', '单季') B14_荞麦_单季
# ('B14', '南瓜', '单季') B14_南瓜_单季
# ('B14', '红薯', '单季') B14_红薯_单季
# ('B14', '莜麦', '单季') B14_莜麦_单季
# ('B14', '大麦', '单季') B14_大麦_单季
# ('B14', '水稻', '单季') B14_水稻_单季
# ('B14', '豇豆', '单季') B14_豇豆_单季
# ('B14', '刀豆', '单季') B14_刀豆_单季
# ('B14', '芸豆', '单季') B14_芸豆_单季
# ('B14', '土豆', '单季') B14_土豆_单季
# ('B14', '西红柿', '单季') B14_西红柿_单季
# ('B14', '茄子', '单季') B14_茄子_单季
# ('B14', '菠菜 ', '单季') B14_菠菜__单季
# ('B14', '青椒', '单季') B14_青椒_单季
# ('B14', '菜花', '单季') B14_菜花_单季
# ('B14', '包菜', '单季') B14_包菜_单季
# ('B14', '油麦菜', '单季') B14_油麦菜_单季
# ('B14', '小青菜', '单季') B14_小青菜_单季
# ('B14', '黄瓜', '单季') B14_黄瓜_单季
# ('B14', '生菜 ', '单季') B14_生菜__单季
# ('B14', '辣椒', '单季') B14_辣椒_单季
# ('B14', '空心菜', '单季') B14_空心菜_单季
# ('B14', '黄心菜', '单季') B14_黄心菜_单季
# ('B14', '芹菜', '单季') B14_芹菜_单季
# ('B14', '大白菜', '单季') B14_大白菜_单季
# ('B14', '白萝卜', '单季') B14_白萝卜_单季
# ('B14', '红萝卜', '单季') B14_红萝卜_单季
# ('B14', '榆黄菇', '单季') B14_榆黄菇_单季
# ('B14', '香菇', '单季') B14_香菇_单季
# ('B14', '白灵菇', '单季') B14_白灵菇_单季
# ('B14', '羊肚菌', '单季') B14_羊肚菌_单季
# ('C1', '黄豆', '单季') C1_黄豆_单季
# ('C1', '黑豆', '单季') C1_黑豆_单季
# ('C1', '红豆', '单季') C1_红豆_单季
# ('C1', '绿豆', '单季') C1_绿豆_单季
# ('C1', '爬豆', '单季') C1_爬豆_单季
# ('C1', '小麦', '单季') C1_小麦_单季
# ('C1', '玉米', '单季') C1_玉米_单季
# ('C1', '谷子', '单季') C1_谷子_单季
# ('C1', '高粱', '单季') C1_高粱_单季
# ('C1', '黍子', '单季') C1_黍子_单季
# ('C1', '荞麦', '单季') C1_荞麦_单季
# ('C1', '南瓜', '单季') C1_南瓜_单季
# ('C1', '红薯', '单季') C1_红薯_单季
# ('C1', '莜麦', '单季') C1_莜麦_单季
# ('C1', '大麦', '单季') C1_大麦_单季
# ('C1', '水稻', '单季') C1_水稻_单季
# ('C1', '豇豆', '单季') C1_豇豆_单季
# ('C1', '刀豆', '单季') C1_刀豆_单季
# ('C1', '芸豆', '单季') C1_芸豆_单季
# ('C1', '土豆', '单季') C1_土豆_单季
# ('C1', '西红柿', '单季') C1_西红柿_单季
# ('C1', '茄子', '单季') C1_茄子_单季
# ('C1', '菠菜 ', '单季') C1_菠菜__单季
# ('C1', '青椒', '单季') C1_青椒_单季
# ('C1', '菜花', '单季') C1_菜花_单季
# ('C1', '包菜', '单季') C1_包菜_单季
# ('C1', '油麦菜', '单季') C1_油麦菜_单季
# ('C1', '小青菜', '单季') C1_小青菜_单季
# ('C1', '黄瓜', '单季') C1_黄瓜_单季
# ('C1', '生菜 ', '单季') C1_生菜__单季
# ('C1', '辣椒', '单季') C1_辣椒_单季
# ('C1', '空心菜', '单季') C1_空心菜_单季
# ('C1', '黄心菜', '单季') C1_黄心菜_单季
# ('C1', '芹菜', '单季') C1_芹菜_单季
# ('C1', '大白菜', '单季') C1_大白菜_单季
# ('C1', '白萝卜', '单季') C1_白萝卜_单季
# ('C1', '红萝卜', '单季') C1_红萝卜_单季
# ('C1', '榆黄菇', '单季') C1_榆黄菇_单季
# ('C1', '香菇', '单季') C1_香菇_单季
# ('C1', '白灵菇', '单季') C1_白灵菇_单季
# ('C1', '羊肚菌', '单季') C1_羊肚菌_单季
# ('C2', '黄豆', '单季') C2_黄豆_单季
# ('C2', '黑豆', '单季') C2_黑豆_单季
# ('C2', '红豆', '单季') C2_红豆_单季
# ('C2', '绿豆', '单季') C2_绿豆_单季
# ('C2', '爬豆', '单季') C2_爬豆_单季
# ('C2', '小麦', '单季') C2_小麦_单季
# ('C2', '玉米', '单季') C2_玉米_单季
# ('C2', '谷子', '单季') C2_谷子_单季
# ('C2', '高粱', '单季') C2_高粱_单季
# ('C2', '黍子', '单季') C2_黍子_单季
# ('C2', '荞麦', '单季') C2_荞麦_单季
# ('C2', '南瓜', '单季') C2_南瓜_单季
# ('C2', '红薯', '单季') C2_红薯_单季
# ('C2', '莜麦', '单季') C2_莜麦_单季
# ('C2', '大麦', '单季') C2_大麦_单季
# ('C2', '水稻', '单季') C2_水稻_单季
# ('C2', '豇豆', '单季') C2_豇豆_单季
# ('C2', '刀豆', '单季') C2_刀豆_单季
# ('C2', '芸豆', '单季') C2_芸豆_单季
# ('C2', '土豆', '单季') C2_土豆_单季
# ('C2', '西红柿', '单季') C2_西红柿_单季
# ('C2', '茄子', '单季') C2_茄子_单季
# ('C2', '菠菜 ', '单季') C2_菠菜__单季
# ('C2', '青椒', '单季') C2_青椒_单季
# ('C2', '菜花', '单季') C2_菜花_单季
# ('C2', '包菜', '单季') C2_包菜_单季
# ('C2', '油麦菜', '单季') C2_油麦菜_单季
# ('C2', '小青菜', '单季') C2_小青菜_单季
# ('C2', '黄瓜', '单季') C2_黄瓜_单季
# ('C2', '生菜 ', '单季') C2_生菜__单季
# ('C2', '辣椒', '单季') C2_辣椒_单季
# ('C2', '空心菜', '单季') C2_空心菜_单季
# ('C2', '黄心菜', '单季') C2_黄心菜_单季
# ('C2', '芹菜', '单季') C2_芹菜_单季
# ('C2', '大白菜', '单季') C2_大白菜_单季
# ('C2', '白萝卜', '单季') C2_白萝卜_单季
# ('C2', '红萝卜', '单季') C2_红萝卜_单季
# ('C2', '榆黄菇', '单季') C2_榆黄菇_单季
# ('C2', '香菇', '单季') C2_香菇_单季
# ('C2', '白灵菇', '单季') C2_白灵菇_单季
# ('C2', '羊肚菌', '单季') C2_羊肚菌_单季
# ('C3', '黄豆', '单季') C3_黄豆_单季
# ('C3', '黑豆', '单季') C3_黑豆_单季
# ('C3', '红豆', '单季') C3_红豆_单季
# ('C3', '绿豆', '单季') C3_绿豆_单季
# ('C3', '爬豆', '单季') C3_爬豆_单季
# ('C3', '小麦', '单季') C3_小麦_单季
# ('C3', '玉米', '单季') C3_玉米_单季
# ('C3', '谷子', '单季') C3_谷子_单季
# ('C3', '高粱', '单季') C3_高粱_单季
# ('C3', '黍子', '单季') C3_黍子_单季
# ('C3', '荞麦', '单季') C3_荞麦_单季
# ('C3', '南瓜', '单季') C3_南瓜_单季
# ('C3', '红薯', '单季') C3_红薯_单季
# ('C3', '莜麦', '单季') C3_莜麦_单季
# ('C3', '大麦', '单季') C3_大麦_单季
# ('C3', '水稻', '单季') C3_水稻_单季
# ('C3', '豇豆', '单季') C3_豇豆_单季
# ('C3', '刀豆', '单季') C3_刀豆_单季
# ('C3', '芸豆', '单季') C3_芸豆_单季
# ('C3', '土豆', '单季') C3_土豆_单季
# ('C3', '西红柿', '单季') C3_西红柿_单季
# ('C3', '茄子', '单季') C3_茄子_单季
# ('C3', '菠菜 ', '单季') C3_菠菜__单季
# ('C3', '青椒', '单季') C3_青椒_单季
# ('C3', '菜花', '单季') C3_菜花_单季
# ('C3', '包菜', '单季') C3_包菜_单季
# ('C3', '油麦菜', '单季') C3_油麦菜_单季
# ('C3', '小青菜', '单季') C3_小青菜_单季
# ('C3', '黄瓜', '单季') C3_黄瓜_单季
# ('C3', '生菜 ', '单季') C3_生菜__单季
# ('C3', '辣椒', '单季') C3_辣椒_单季
# ('C3', '空心菜', '单季') C3_空心菜_单季
# ('C3', '黄心菜', '单季') C3_黄心菜_单季
# ('C3', '芹菜', '单季') C3_芹菜_单季
# ('C3', '大白菜', '单季') C3_大白菜_单季
# ('C3', '白萝卜', '单季') C3_白萝卜_单季
# ('C3', '红萝卜', '单季') C3_红萝卜_单季
# ('C3', '榆黄菇', '单季') C3_榆黄菇_单季
# ('C3', '香菇', '单季') C3_香菇_单季
# ('C3', '白灵菇', '单季') C3_白灵菇_单季
# ('C3', '羊肚菌', '单季') C3_羊肚菌_单季
# ('C4', '黄豆', '单季') C4_黄豆_单季
# ('C4', '黑豆', '单季') C4_黑豆_单季
# ('C4', '红豆', '单季') C4_红豆_单季
# ('C4', '绿豆', '单季') C4_绿豆_单季
# ('C4', '爬豆', '单季') C4_爬豆_单季
# ('C4', '小麦', '单季') C4_小麦_单季
# ('C4', '玉米', '单季') C4_玉米_单季
# ('C4', '谷子', '单季') C4_谷子_单季
# ('C4', '高粱', '单季') C4_高粱_单季
# ('C4', '黍子', '单季') C4_黍子_单季
# ('C4', '荞麦', '单季') C4_荞麦_单季
# ('C4', '南瓜', '单季') C4_南瓜_单季
# ('C4', '红薯', '单季') C4_红薯_单季
# ('C4', '莜麦', '单季') C4_莜麦_单季
# ('C4', '大麦', '单季') C4_大麦_单季
# ('C4', '水稻', '单季') C4_水稻_单季
# ('C4', '豇豆', '单季') C4_豇豆_单季
# ('C4', '刀豆', '单季') C4_刀豆_单季
# ('C4', '芸豆', '单季') C4_芸豆_单季
# ('C4', '土豆', '单季') C4_土豆_单季
# ('C4', '西红柿', '单季') C4_西红柿_单季
# ('C4', '茄子', '单季') C4_茄子_单季
# ('C4', '菠菜 ', '单季') C4_菠菜__单季
# ('C4', '青椒', '单季') C4_青椒_单季
# ('C4', '菜花', '单季') C4_菜花_单季
# ('C4', '包菜', '单季') C4_包菜_单季
# ('C4', '油麦菜', '单季') C4_油麦菜_单季
# ('C4', '小青菜', '单季') C4_小青菜_单季
# ('C4', '黄瓜', '单季') C4_黄瓜_单季
# ('C4', '生菜 ', '单季') C4_生菜__单季
# ('C4', '辣椒', '单季') C4_辣椒_单季
# ('C4', '空心菜', '单季') C4_空心菜_单季
# ('C4', '黄心菜', '单季') C4_黄心菜_单季
# ('C4', '芹菜', '单季') C4_芹菜_单季
# ('C4', '大白菜', '单季') C4_大白菜_单季
# ('C4', '白萝卜', '单季') C4_白萝卜_单季
# ('C4', '红萝卜', '单季') C4_红萝卜_单季
# ('C4', '榆黄菇', '单季') C4_榆黄菇_单季
# ('C4', '香菇', '单季') C4_香菇_单季
# ('C4', '白灵菇', '单季') C4_白灵菇_单季
# ('C4', '羊肚菌', '单季') C4_羊肚菌_单季
# ('C5', '黄豆', '单季') C5_黄豆_单季
# ('C5', '黑豆', '单季') C5_黑豆_单季
# ('C5', '红豆', '单季') C5_红豆_单季
# ('C5', '绿豆', '单季') C5_绿豆_单季
# ('C5', '爬豆', '单季') C5_爬豆_单季
# ('C5', '小麦', '单季') C5_小麦_单季
# ('C5', '玉米', '单季') C5_玉米_单季
# ('C5', '谷子', '单季') C5_谷子_单季
# ('C5', '高粱', '单季') C5_高粱_单季
# ('C5', '黍子', '单季') C5_黍子_单季
# ('C5', '荞麦', '单季') C5_荞麦_单季
# ('C5', '南瓜', '单季') C5_南瓜_单季
# ('C5', '红薯', '单季') C5_红薯_单季
# ('C5', '莜麦', '单季') C5_莜麦_单季
# ('C5', '大麦', '单季') C5_大麦_单季
# ('C5', '水稻', '单季') C5_水稻_单季
# ('C5', '豇豆', '单季') C5_豇豆_单季
# ('C5', '刀豆', '单季') C5_刀豆_单季
# ('C5', '芸豆', '单季') C5_芸豆_单季
# ('C5', '土豆', '单季') C5_土豆_单季
# ('C5', '西红柿', '单季') C5_西红柿_单季
# ('C5', '茄子', '单季') C5_茄子_单季
# ('C5', '菠菜 ', '单季') C5_菠菜__单季
# ('C5', '青椒', '单季') C5_青椒_单季
# ('C5', '菜花', '单季') C5_菜花_单季
# ('C5', '包菜', '单季') C5_包菜_单季
# ('C5', '油麦菜', '单季') C5_油麦菜_单季
# ('C5', '小青菜', '单季') C5_小青菜_单季
# ('C5', '黄瓜', '单季') C5_黄瓜_单季
# ('C5', '生菜 ', '单季') C5_生菜__单季
# ('C5', '辣椒', '单季') C5_辣椒_单季
# ('C5', '空心菜', '单季') C5_空心菜_单季
# ('C5', '黄心菜', '单季') C5_黄心菜_单季
# ('C5', '芹菜', '单季') C5_芹菜_单季
# ('C5', '大白菜', '单季') C5_大白菜_单季
# ('C5', '白萝卜', '单季') C5_白萝卜_单季
# ('C5', '红萝卜', '单季') C5_红萝卜_单季
# ('C5', '榆黄菇', '单季') C5_榆黄菇_单季
# ('C5', '香菇', '单季') C5_香菇_单季
# ('C5', '白灵菇', '单季') C5_白灵菇_单季
# ('C5', '羊肚菌', '单季') C5_羊肚菌_单季
# ('C6', '黄豆', '单季') C6_黄豆_单季
# ('C6', '黑豆', '单季') C6_黑豆_单季
# ('C6', '红豆', '单季') C6_红豆_单季
# ('C6', '绿豆', '单季') C6_绿豆_单季
# ('C6', '爬豆', '单季') C6_爬豆_单季
# ('C6', '小麦', '单季') C6_小麦_单季
# ('C6', '玉米', '单季') C6_玉米_单季
# ('C6', '谷子', '单季') C6_谷子_单季
# ('C6', '高粱', '单季') C6_高粱_单季
# ('C6', '黍子', '单季') C6_黍子_单季
# ('C6', '荞麦', '单季') C6_荞麦_单季
# ('C6', '南瓜', '单季') C6_南瓜_单季
# ('C6', '红薯', '单季') C6_红薯_单季
# ('C6', '莜麦', '单季') C6_莜麦_单季
# ('C6', '大麦', '单季') C6_大麦_单季
# ('C6', '水稻', '单季') C6_水稻_单季
# ('C6', '豇豆', '单季') C6_豇豆_单季
# ('C6', '刀豆', '单季') C6_刀豆_单季
# ('C6', '芸豆', '单季') C6_芸豆_单季
# ('C6', '土豆', '单季') C6_土豆_单季
# ('C6', '西红柿', '单季') C6_西红柿_单季
# ('C6', '茄子', '单季') C6_茄子_单季
# ('C6', '菠菜 ', '单季') C6_菠菜__单季
# ('C6', '青椒', '单季') C6_青椒_单季
# ('C6', '菜花', '单季') C6_菜花_单季
# ('C6', '包菜', '单季') C6_包菜_单季
# ('C6', '油麦菜', '单季') C6_油麦菜_单季
# ('C6', '小青菜', '单季') C6_小青菜_单季
# ('C6', '黄瓜', '单季') C6_黄瓜_单季
# ('C6', '生菜 ', '单季') C6_生菜__单季
# ('C6', '辣椒', '单季') C6_辣椒_单季
# ('C6', '空心菜', '单季') C6_空心菜_单季
# ('C6', '黄心菜', '单季') C6_黄心菜_单季
# ('C6', '芹菜', '单季') C6_芹菜_单季
# ('C6', '大白菜', '单季') C6_大白菜_单季
# ('C6', '白萝卜', '单季') C6_白萝卜_单季
# ('C6', '红萝卜', '单季') C6_红萝卜_单季
# ('C6', '榆黄菇', '单季') C6_榆黄菇_单季
# ('C6', '香菇', '单季') C6_香菇_单季
# ('C6', '白灵菇', '单季') C6_白灵菇_单季
# ('C6', '羊肚菌', '单季') C6_羊肚菌_单季
# ('D1', '黄豆', '单季') D1_黄豆_单季
# ('D1', '黑豆', '单季') D1_黑豆_单季
# ('D1', '红豆', '单季') D1_红豆_单季
# ('D1', '绿豆', '单季') D1_绿豆_单季
# ('D1', '爬豆', '单季') D1_爬豆_单季
# ('D1', '小麦', '单季') D1_小麦_单季
# ('D1', '玉米', '单季') D1_玉米_单季
# ('D1', '谷子', '单季') D1_谷子_单季
# ('D1', '高粱', '单季') D1_高粱_单季
# ('D1', '黍子', '单季') D1_黍子_单季
# ('D1', '荞麦', '单季') D1_荞麦_单季
# ('D1', '南瓜', '单季') D1_南瓜_单季
# ('D1', '红薯', '单季') D1_红薯_单季
# ('D1', '莜麦', '单季') D1_莜麦_单季
# ('D1', '大麦', '单季') D1_大麦_单季
# ('D1', '水稻', '单季') D1_水稻_单季
# ('D1', '豇豆', '单季') D1_豇豆_单季
# ('D1', '刀豆', '单季') D1_刀豆_单季
# ('D1', '芸豆', '单季') D1_芸豆_单季
# ('D1', '土豆', '单季') D1_土豆_单季
# ('D1', '西红柿', '单季') D1_西红柿_单季
# ('D1', '茄子', '单季') D1_茄子_单季
# ('D1', '菠菜 ', '单季') D1_菠菜__单季
# ('D1', '青椒', '单季') D1_青椒_单季
# ('D1', '菜花', '单季') D1_菜花_单季
# ('D1', '包菜', '单季') D1_包菜_单季
# ('D1', '油麦菜', '单季') D1_油麦菜_单季
# ('D1', '小青菜', '单季') D1_小青菜_单季
# ('D1', '黄瓜', '单季') D1_黄瓜_单季
# ('D1', '生菜 ', '单季') D1_生菜__单季
# ('D1', '辣椒', '单季') D1_辣椒_单季
# ('D1', '空心菜', '单季') D1_空心菜_单季
# ('D1', '黄心菜', '单季') D1_黄心菜_单季
# ('D1', '芹菜', '单季') D1_芹菜_单季
# ('D1', '大白菜', '单季') D1_大白菜_单季
# ('D1', '白萝卜', '单季') D1_白萝卜_单季
# ('D1', '红萝卜', '单季') D1_红萝卜_单季
# ('D1', '榆黄菇', '单季') D1_榆黄菇_单季
# ('D1', '香菇', '单季') D1_香菇_单季
# ('D1', '白灵菇', '单季') D1_白灵菇_单季
# ('D1', '羊肚菌', '单季') D1_羊肚菌_单季
# ('D1', '黄豆', '第一季') D1_黄豆_第一季
# ('D1', '黑豆', '第一季') D1_黑豆_第一季
# ('D1', '红豆', '第一季') D1_红豆_第一季
# ('D1', '绿豆', '第一季') D1_绿豆_第一季
# ('D1', '爬豆', '第一季') D1_爬豆_第一季
# ('D1', '小麦', '第一季') D1_小麦_第一季
# ('D1', '玉米', '第一季') D1_玉米_第一季
# ('D1', '谷子', '第一季') D1_谷子_第一季
# ('D1', '高粱', '第一季') D1_高粱_第一季
# ('D1', '黍子', '第一季') D1_黍子_第一季
# ('D1', '荞麦', '第一季') D1_荞麦_第一季
# ('D1', '南瓜', '第一季') D1_南瓜_第一季
# ('D1', '红薯', '第一季') D1_红薯_第一季
# ('D1', '莜麦', '第一季') D1_莜麦_第一季
# ('D1', '大麦', '第一季') D1_大麦_第一季
# ('D1', '水稻', '第一季') D1_水稻_第一季
# ('D1', '豇豆', '第一季') D1_豇豆_第一季
# ('D1', '刀豆', '第一季') D1_刀豆_第一季
# ('D1', '芸豆', '第一季') D1_芸豆_第一季
# ('D1', '土豆', '第一季') D1_土豆_第一季
# ('D1', '西红柿', '第一季') D1_西红柿_第一季
# ('D1', '茄子', '第一季') D1_茄子_第一季
# ('D1', '菠菜 ', '第一季') D1_菠菜__第一季
# ('D1', '青椒', '第一季') D1_青椒_第一季
# ('D1', '菜花', '第一季') D1_菜花_第一季
# ('D1', '包菜', '第一季') D1_包菜_第一季
# ('D1', '油麦菜', '第一季') D1_油麦菜_第一季
# ('D1', '小青菜', '第一季') D1_小青菜_第一季
# ('D1', '黄瓜', '第一季') D1_黄瓜_第一季
# ('D1', '生菜 ', '第一季') D1_生菜__第一季
# ('D1', '辣椒', '第一季') D1_辣椒_第一季
# ('D1', '空心菜', '第一季') D1_空心菜_第一季
# ('D1', '黄心菜', '第一季') D1_黄心菜_第一季
# ('D1', '芹菜', '第一季') D1_芹菜_第一季
# ('D1', '大白菜', '第一季') D1_大白菜_第一季
# ('D1', '白萝卜', '第一季') D1_白萝卜_第一季
# ('D1', '红萝卜', '第一季') D1_红萝卜_第一季
# ('D1', '榆黄菇', '第一季') D1_榆黄菇_第一季
# ('D1', '香菇', '第一季') D1_香菇_第一季
# ('D1', '白灵菇', '第一季') D1_白灵菇_第一季
# ('D1', '羊肚菌', '第一季') D1_羊肚菌_第一季
# ('D1', '黄豆', '第二季') D1_黄豆_第二季
# ('D1', '黑豆', '第二季') D1_黑豆_第二季
# ('D1', '红豆', '第二季') D1_红豆_第二季
# ('D1', '绿豆', '第二季') D1_绿豆_第二季
# ('D1', '爬豆', '第二季') D1_爬豆_第二季
# ('D1', '小麦', '第二季') D1_小麦_第二季
# ('D1', '玉米', '第二季') D1_玉米_第二季
# ('D1', '谷子', '第二季') D1_谷子_第二季
# ('D1', '高粱', '第二季') D1_高粱_第二季
# ('D1', '黍子', '第二季') D1_黍子_第二季
# ('D1', '荞麦', '第二季') D1_荞麦_第二季
# ('D1', '南瓜', '第二季') D1_南瓜_第二季
# ('D1', '红薯', '第二季') D1_红薯_第二季
# ('D1', '莜麦', '第二季') D1_莜麦_第二季
# ('D1', '大麦', '第二季') D1_大麦_第二季
# ('D1', '水稻', '第二季') D1_水稻_第二季
# ('D1', '豇豆', '第二季') D1_豇豆_第二季
# ('D1', '刀豆', '第二季') D1_刀豆_第二季
# ('D1', '芸豆', '第二季') D1_芸豆_第二季
# ('D1', '土豆', '第二季') D1_土豆_第二季
# ('D1', '西红柿', '第二季') D1_西红柿_第二季
# ('D1', '茄子', '第二季') D1_茄子_第二季
# ('D1', '菠菜 ', '第二季') D1_菠菜__第二季
# ('D1', '青椒', '第二季') D1_青椒_第二季
# ('D1', '菜花', '第二季') D1_菜花_第二季
# ('D1', '包菜', '第二季') D1_包菜_第二季
# ('D1', '油麦菜', '第二季') D1_油麦菜_第二季
# ('D1', '小青菜', '第二季') D1_小青菜_第二季
# ('D1', '黄瓜', '第二季') D1_黄瓜_第二季
# ('D1', '生菜 ', '第二季') D1_生菜__第二季
# ('D1', '辣椒', '第二季') D1_辣椒_第二季
# ('D1', '空心菜', '第二季') D1_空心菜_第二季
# ('D1', '黄心菜', '第二季') D1_黄心菜_第二季
# ('D1', '芹菜', '第二季') D1_芹菜_第二季
# ('D1', '大白菜', '第二季') D1_大白菜_第二季
# ('D1', '白萝卜', '第二季') D1_白萝卜_第二季
# ('D1', '红萝卜', '第二季') D1_红萝卜_第二季
# ('D1', '榆黄菇', '第二季') D1_榆黄菇_第二季
# ('D1', '香菇', '第二季') D1_香菇_第二季
# ('D1', '白灵菇', '第二季') D1_白灵菇_第二季
# ('D1', '羊肚菌', '第二季') D1_羊肚菌_第二季
# ('D2', '黄豆', '单季') D2_黄豆_单季
# ('D2', '黑豆', '单季') D2_黑豆_单季
# ('D2', '红豆', '单季') D2_红豆_单季
# ('D2', '绿豆', '单季') D2_绿豆_单季
# ('D2', '爬豆', '单季') D2_爬豆_单季
# ('D2', '小麦', '单季') D2_小麦_单季
# ('D2', '玉米', '单季') D2_玉米_单季
# ('D2', '谷子', '单季') D2_谷子_单季
# ('D2', '高粱', '单季') D2_高粱_单季
# ('D2', '黍子', '单季') D2_黍子_单季
# ('D2', '荞麦', '单季') D2_荞麦_单季
# ('D2', '南瓜', '单季') D2_南瓜_单季
# ('D2', '红薯', '单季') D2_红薯_单季
# ('D2', '莜麦', '单季') D2_莜麦_单季
# ('D2', '大麦', '单季') D2_大麦_单季
# ('D2', '水稻', '单季') D2_水稻_单季
# ('D2', '豇豆', '单季') D2_豇豆_单季
# ('D2', '刀豆', '单季') D2_刀豆_单季
# ('D2', '芸豆', '单季') D2_芸豆_单季
# ('D2', '土豆', '单季') D2_土豆_单季
# ('D2', '西红柿', '单季') D2_西红柿_单季
# ('D2', '茄子', '单季') D2_茄子_单季
# ('D2', '菠菜 ', '单季') D2_菠菜__单季
# ('D2', '青椒', '单季') D2_青椒_单季
# ('D2', '菜花', '单季') D2_菜花_单季
# ('D2', '包菜', '单季') D2_包菜_单季
# ('D2', '油麦菜', '单季') D2_油麦菜_单季
# ('D2', '小青菜', '单季') D2_小青菜_单季
# ('D2', '黄瓜', '单季') D2_黄瓜_单季
# ('D2', '生菜 ', '单季') D2_生菜__单季
# ('D2', '辣椒', '单季') D2_辣椒_单季
# ('D2', '空心菜', '单季') D2_空心菜_单季
# ('D2', '黄心菜', '单季') D2_黄心菜_单季
# ('D2', '芹菜', '单季') D2_芹菜_单季
# ('D2', '大白菜', '单季') D2_大白菜_单季
# ('D2', '白萝卜', '单季') D2_白萝卜_单季
# ('D2', '红萝卜', '单季') D2_红萝卜_单季
# ('D2', '榆黄菇', '单季') D2_榆黄菇_单季
# ('D2', '香菇', '单季') D2_香菇_单季
# ('D2', '白灵菇', '单季') D2_白灵菇_单季
# ('D2', '羊肚菌', '单季') D2_羊肚菌_单季
# ('D2', '黄豆', '第一季') D2_黄豆_第一季
# ('D2', '黑豆', '第一季') D2_黑豆_第一季
# ('D2', '红豆', '第一季') D2_红豆_第一季
# ('D2', '绿豆', '第一季') D2_绿豆_第一季
# ('D2', '爬豆', '第一季') D2_爬豆_第一季
# ('D2', '小麦', '第一季') D2_小麦_第一季
# ('D2', '玉米', '第一季') D2_玉米_第一季
# ('D2', '谷子', '第一季') D2_谷子_第一季
# ('D2', '高粱', '第一季') D2_高粱_第一季
# ('D2', '黍子', '第一季') D2_黍子_第一季
# ('D2', '荞麦', '第一季') D2_荞麦_第一季
# ('D2', '南瓜', '第一季') D2_南瓜_第一季
# ('D2', '红薯', '第一季') D2_红薯_第一季
# ('D2', '莜麦', '第一季') D2_莜麦_第一季
# ('D2', '大麦', '第一季') D2_大麦_第一季
# ('D2', '水稻', '第一季') D2_水稻_第一季
# ('D2', '豇豆', '第一季') D2_豇豆_第一季
# ('D2', '刀豆', '第一季') D2_刀豆_第一季
# ('D2', '芸豆', '第一季') D2_芸豆_第一季
# ('D2', '土豆', '第一季') D2_土豆_第一季
# ('D2', '西红柿', '第一季') D2_西红柿_第一季
# ('D2', '茄子', '第一季') D2_茄子_第一季
# ('D2', '菠菜 ', '第一季') D2_菠菜__第一季
# ('D2', '青椒', '第一季') D2_青椒_第一季
# ('D2', '菜花', '第一季') D2_菜花_第一季
# ('D2', '包菜', '第一季') D2_包菜_第一季
# ('D2', '油麦菜', '第一季') D2_油麦菜_第一季
# ('D2', '小青菜', '第一季') D2_小青菜_第一季
# ('D2', '黄瓜', '第一季') D2_黄瓜_第一季
# ('D2', '生菜 ', '第一季') D2_生菜__第一季
# ('D2', '辣椒', '第一季') D2_辣椒_第一季
# ('D2', '空心菜', '第一季') D2_空心菜_第一季
# ('D2', '黄心菜', '第一季') D2_黄心菜_第一季
# ('D2', '芹菜', '第一季') D2_芹菜_第一季
# ('D2', '大白菜', '第一季') D2_大白菜_第一季
# ('D2', '白萝卜', '第一季') D2_白萝卜_第一季
# ('D2', '红萝卜', '第一季') D2_红萝卜_第一季
# ('D2', '榆黄菇', '第一季') D2_榆黄菇_第一季
# ('D2', '香菇', '第一季') D2_香菇_第一季
# ('D2', '白灵菇', '第一季') D2_白灵菇_第一季
# ('D2', '羊肚菌', '第一季') D2_羊肚菌_第一季
# ('D2', '黄豆', '第二季') D2_黄豆_第二季
# ('D2', '黑豆', '第二季') D2_黑豆_第二季
# ('D2', '红豆', '第二季') D2_红豆_第二季
# ('D2', '绿豆', '第二季') D2_绿豆_第二季
# ('D2', '爬豆', '第二季') D2_爬豆_第二季
# ('D2', '小麦', '第二季') D2_小麦_第二季
# ('D2', '玉米', '第二季') D2_玉米_第二季
# ('D2', '谷子', '第二季') D2_谷子_第二季
# ('D2', '高粱', '第二季') D2_高粱_第二季
# ('D2', '黍子', '第二季') D2_黍子_第二季
# ('D2', '荞麦', '第二季') D2_荞麦_第二季
# ('D2', '南瓜', '第二季') D2_南瓜_第二季
# ('D2', '红薯', '第二季') D2_红薯_第二季
# ('D2', '莜麦', '第二季') D2_莜麦_第二季
# ('D2', '大麦', '第二季') D2_大麦_第二季
# ('D2', '水稻', '第二季') D2_水稻_第二季
# ('D2', '豇豆', '第二季') D2_豇豆_第二季
# ('D2', '刀豆', '第二季') D2_刀豆_第二季
# ('D2', '芸豆', '第二季') D2_芸豆_第二季
# ('D2', '土豆', '第二季') D2_土豆_第二季
# ('D2', '西红柿', '第二季') D2_西红柿_第二季
# ('D2', '茄子', '第二季') D2_茄子_第二季
# ('D2', '菠菜 ', '第二季') D2_菠菜__第二季
# ('D2', '青椒', '第二季') D2_青椒_第二季
# ('D2', '菜花', '第二季') D2_菜花_第二季
# ('D2', '包菜', '第二季') D2_包菜_第二季
# ('D2', '油麦菜', '第二季') D2_油麦菜_第二季
# ('D2', '小青菜', '第二季') D2_小青菜_第二季
# ('D2', '黄瓜', '第二季') D2_黄瓜_第二季
# ('D2', '生菜 ', '第二季') D2_生菜__第二季
# ('D2', '辣椒', '第二季') D2_辣椒_第二季
# ('D2', '空心菜', '第二季') D2_空心菜_第二季
# ('D2', '黄心菜', '第二季') D2_黄心菜_第二季
# ('D2', '芹菜', '第二季') D2_芹菜_第二季
# ('D2', '大白菜', '第二季') D2_大白菜_第二季
# ('D2', '白萝卜', '第二季') D2_白萝卜_第二季
# ('D2', '红萝卜', '第二季') D2_红萝卜_第二季
# ('D2', '榆黄菇', '第二季') D2_榆黄菇_第二季
# ('D2', '香菇', '第二季') D2_香菇_第二季
# ('D2', '白灵菇', '第二季') D2_白灵菇_第二季
# ('D2', '羊肚菌', '第二季') D2_羊肚菌_第二季
# ('D3', '黄豆', '单季') D3_黄豆_单季
# ('D3', '黑豆', '单季') D3_黑豆_单季
# ('D3', '红豆', '单季') D3_红豆_单季
# ('D3', '绿豆', '单季') D3_绿豆_单季
# ('D3', '爬豆', '单季') D3_爬豆_单季
# ('D3', '小麦', '单季') D3_小麦_单季
# ('D3', '玉米', '单季') D3_玉米_单季
# ('D3', '谷子', '单季') D3_谷子_单季
# ('D3', '高粱', '单季') D3_高粱_单季
# ('D3', '黍子', '单季') D3_黍子_单季
# ('D3', '荞麦', '单季') D3_荞麦_单季
# ('D3', '南瓜', '单季') D3_南瓜_单季
# ('D3', '红薯', '单季') D3_红薯_单季
# ('D3', '莜麦', '单季') D3_莜麦_单季
# ('D3', '大麦', '单季') D3_大麦_单季
# ('D3', '水稻', '单季') D3_水稻_单季
# ('D3', '豇豆', '单季') D3_豇豆_单季
# ('D3', '刀豆', '单季') D3_刀豆_单季
# ('D3', '芸豆', '单季') D3_芸豆_单季
# ('D3', '土豆', '单季') D3_土豆_单季
# ('D3', '西红柿', '单季') D3_西红柿_单季
# ('D3', '茄子', '单季') D3_茄子_单季
# ('D3', '菠菜 ', '单季') D3_菠菜__单季
# ('D3', '青椒', '单季') D3_青椒_单季
# ('D3', '菜花', '单季') D3_菜花_单季
# ('D3', '包菜', '单季') D3_包菜_单季
# ('D3', '油麦菜', '单季') D3_油麦菜_单季
# ('D3', '小青菜', '单季') D3_小青菜_单季
# ('D3', '黄瓜', '单季') D3_黄瓜_单季
# ('D3', '生菜 ', '单季') D3_生菜__单季
# ('D3', '辣椒', '单季') D3_辣椒_单季
# ('D3', '空心菜', '单季') D3_空心菜_单季
# ('D3', '黄心菜', '单季') D3_黄心菜_单季
# ('D3', '芹菜', '单季') D3_芹菜_单季
# ('D3', '大白菜', '单季') D3_大白菜_单季
# ('D3', '白萝卜', '单季') D3_白萝卜_单季
# ('D3', '红萝卜', '单季') D3_红萝卜_单季
# ('D3', '榆黄菇', '单季') D3_榆黄菇_单季
# ('D3', '香菇', '单季') D3_香菇_单季
# ('D3', '白灵菇', '单季') D3_白灵菇_单季
# ('D3', '羊肚菌', '单季') D3_羊肚菌_单季
# ('D3', '黄豆', '第一季') D3_黄豆_第一季
# ('D3', '黑豆', '第一季') D3_黑豆_第一季
# ('D3', '红豆', '第一季') D3_红豆_第一季
# ('D3', '绿豆', '第一季') D3_绿豆_第一季
# ('D3', '爬豆', '第一季') D3_爬豆_第一季
# ('D3', '小麦', '第一季') D3_小麦_第一季
# ('D3', '玉米', '第一季') D3_玉米_第一季
# ('D3', '谷子', '第一季') D3_谷子_第一季
# ('D3', '高粱', '第一季') D3_高粱_第一季
# ('D3', '黍子', '第一季') D3_黍子_第一季
# ('D3', '荞麦', '第一季') D3_荞麦_第一季
# ('D3', '南瓜', '第一季') D3_南瓜_第一季
# ('D3', '红薯', '第一季') D3_红薯_第一季
# ('D3', '莜麦', '第一季') D3_莜麦_第一季
# ('D3', '大麦', '第一季') D3_大麦_第一季
# ('D3', '水稻', '第一季') D3_水稻_第一季
# ('D3', '豇豆', '第一季') D3_豇豆_第一季
# ('D3', '刀豆', '第一季') D3_刀豆_第一季
# ('D3', '芸豆', '第一季') D3_芸豆_第一季
# ('D3', '土豆', '第一季') D3_土豆_第一季
# ('D3', '西红柿', '第一季') D3_西红柿_第一季
# ('D3', '茄子', '第一季') D3_茄子_第一季
# ('D3', '菠菜 ', '第一季') D3_菠菜__第一季
# ('D3', '青椒', '第一季') D3_青椒_第一季
# ('D3', '菜花', '第一季') D3_菜花_第一季
# ('D3', '包菜', '第一季') D3_包菜_第一季
# ('D3', '油麦菜', '第一季') D3_油麦菜_第一季
# ('D3', '小青菜', '第一季') D3_小青菜_第一季
# ('D3', '黄瓜', '第一季') D3_黄瓜_第一季
# ('D3', '生菜 ', '第一季') D3_生菜__第一季
# ('D3', '辣椒', '第一季') D3_辣椒_第一季
# ('D3', '空心菜', '第一季') D3_空心菜_第一季
# ('D3', '黄心菜', '第一季') D3_黄心菜_第一季
# ('D3', '芹菜', '第一季') D3_芹菜_第一季
# ('D3', '大白菜', '第一季') D3_大白菜_第一季
# ('D3', '白萝卜', '第一季') D3_白萝卜_第一季
# ('D3', '红萝卜', '第一季') D3_红萝卜_第一季
# ('D3', '榆黄菇', '第一季') D3_榆黄菇_第一季
# ('D3', '香菇', '第一季') D3_香菇_第一季
# ('D3', '白灵菇', '第一季') D3_白灵菇_第一季
# ('D3', '羊肚菌', '第一季') D3_羊肚菌_第一季
# ('D3', '黄豆', '第二季') D3_黄豆_第二季
# ('D3', '黑豆', '第二季') D3_黑豆_第二季
# ('D3', '红豆', '第二季') D3_红豆_第二季
# ('D3', '绿豆', '第二季') D3_绿豆_第二季
# ('D3', '爬豆', '第二季') D3_爬豆_第二季
# ('D3', '小麦', '第二季') D3_小麦_第二季
# ('D3', '玉米', '第二季') D3_玉米_第二季
# ('D3', '谷子', '第二季') D3_谷子_第二季
# ('D3', '高粱', '第二季') D3_高粱_第二季
# ('D3', '黍子', '第二季') D3_黍子_第二季
# ('D3', '荞麦', '第二季') D3_荞麦_第二季
# ('D3', '南瓜', '第二季') D3_南瓜_第二季
# ('D3', '红薯', '第二季') D3_红薯_第二季
# ('D3', '莜麦', '第二季') D3_莜麦_第二季
# ('D3', '大麦', '第二季') D3_大麦_第二季
# ('D3', '水稻', '第二季') D3_水稻_第二季
# ('D3', '豇豆', '第二季') D3_豇豆_第二季
# ('D3', '刀豆', '第二季') D3_刀豆_第二季
# ('D3', '芸豆', '第二季') D3_芸豆_第二季
# ('D3', '土豆', '第二季') D3_土豆_第二季
# ('D3', '西红柿', '第二季') D3_西红柿_第二季
# ('D3', '茄子', '第二季') D3_茄子_第二季
# ('D3', '菠菜 ', '第二季') D3_菠菜__第二季
# ('D3', '青椒', '第二季') D3_青椒_第二季
# ('D3', '菜花', '第二季') D3_菜花_第二季
# ('D3', '包菜', '第二季') D3_包菜_第二季
# ('D3', '油麦菜', '第二季') D3_油麦菜_第二季
# ('D3', '小青菜', '第二季') D3_小青菜_第二季
# ('D3', '黄瓜', '第二季') D3_黄瓜_第二季
# ('D3', '生菜 ', '第二季') D3_生菜__第二季
# ('D3', '辣椒', '第二季') D3_辣椒_第二季
# ('D3', '空心菜', '第二季') D3_空心菜_第二季
# ('D3', '黄心菜', '第二季') D3_黄心菜_第二季
# ('D3', '芹菜', '第二季') D3_芹菜_第二季
# ('D3', '大白菜', '第二季') D3_大白菜_第二季
# ('D3', '白萝卜', '第二季') D3_白萝卜_第二季
# ('D3', '红萝卜', '第二季') D3_红萝卜_第二季
# ('D3', '榆黄菇', '第二季') D3_榆黄菇_第二季
# ('D3', '香菇', '第二季') D3_香菇_第二季
# ('D3', '白灵菇', '第二季') D3_白灵菇_第二季
# ('D3', '羊肚菌', '第二季') D3_羊肚菌_第二季
# ('D4', '黄豆', '单季') D4_黄豆_单季
# ('D4', '黑豆', '单季') D4_黑豆_单季
# ('D4', '红豆', '单季') D4_红豆_单季
# ('D4', '绿豆', '单季') D4_绿豆_单季
# ('D4', '爬豆', '单季') D4_爬豆_单季
# ('D4', '小麦', '单季') D4_小麦_单季
# ('D4', '玉米', '单季') D4_玉米_单季
# ('D4', '谷子', '单季') D4_谷子_单季
# ('D4', '高粱', '单季') D4_高粱_单季
# ('D4', '黍子', '单季') D4_黍子_单季
# ('D4', '荞麦', '单季') D4_荞麦_单季
# ('D4', '南瓜', '单季') D4_南瓜_单季
# ('D4', '红薯', '单季') D4_红薯_单季
# ('D4', '莜麦', '单季') D4_莜麦_单季
# ('D4', '大麦', '单季') D4_大麦_单季
# ('D4', '水稻', '单季') D4_水稻_单季
# ('D4', '豇豆', '单季') D4_豇豆_单季
# ('D4', '刀豆', '单季') D4_刀豆_单季
# ('D4', '芸豆', '单季') D4_芸豆_单季
# ('D4', '土豆', '单季') D4_土豆_单季
# ('D4', '西红柿', '单季') D4_西红柿_单季
# ('D4', '茄子', '单季') D4_茄子_单季
# ('D4', '菠菜 ', '单季') D4_菠菜__单季
# ('D4', '青椒', '单季') D4_青椒_单季
# ('D4', '菜花', '单季') D4_菜花_单季
# ('D4', '包菜', '单季') D4_包菜_单季
# ('D4', '油麦菜', '单季') D4_油麦菜_单季
# ('D4', '小青菜', '单季') D4_小青菜_单季
# ('D4', '黄瓜', '单季') D4_黄瓜_单季
# ('D4', '生菜 ', '单季') D4_生菜__单季
# ('D4', '辣椒', '单季') D4_辣椒_单季
# ('D4', '空心菜', '单季') D4_空心菜_单季
# ('D4', '黄心菜', '单季') D4_黄心菜_单季
# ('D4', '芹菜', '单季') D4_芹菜_单季
# ('D4', '大白菜', '单季') D4_大白菜_单季
# ('D4', '白萝卜', '单季') D4_白萝卜_单季
# ('D4', '红萝卜', '单季') D4_红萝卜_单季
# ('D4', '榆黄菇', '单季') D4_榆黄菇_单季
# ('D4', '香菇', '单季') D4_香菇_单季
# ('D4', '白灵菇', '单季') D4_白灵菇_单季
# ('D4', '羊肚菌', '单季') D4_羊肚菌_单季
# ('D4', '黄豆', '第一季') D4_黄豆_第一季
# ('D4', '黑豆', '第一季') D4_黑豆_第一季
# ('D4', '红豆', '第一季') D4_红豆_第一季
# ('D4', '绿豆', '第一季') D4_绿豆_第一季
# ('D4', '爬豆', '第一季') D4_爬豆_第一季
# ('D4', '小麦', '第一季') D4_小麦_第一季
# ('D4', '玉米', '第一季') D4_玉米_第一季
# ('D4', '谷子', '第一季') D4_谷子_第一季
# ('D4', '高粱', '第一季') D4_高粱_第一季
# ('D4', '黍子', '第一季') D4_黍子_第一季
# ('D4', '荞麦', '第一季') D4_荞麦_第一季
# ('D4', '南瓜', '第一季') D4_南瓜_第一季
# ('D4', '红薯', '第一季') D4_红薯_第一季
# ('D4', '莜麦', '第一季') D4_莜麦_第一季
# ('D4', '大麦', '第一季') D4_大麦_第一季
# ('D4', '水稻', '第一季') D4_水稻_第一季
# ('D4', '豇豆', '第一季') D4_豇豆_第一季
# ('D4', '刀豆', '第一季') D4_刀豆_第一季
# ('D4', '芸豆', '第一季') D4_芸豆_第一季
# ('D4', '土豆', '第一季') D4_土豆_第一季
# ('D4', '西红柿', '第一季') D4_西红柿_第一季
# ('D4', '茄子', '第一季') D4_茄子_第一季
# ('D4', '菠菜 ', '第一季') D4_菠菜__第一季
# ('D4', '青椒', '第一季') D4_青椒_第一季
# ('D4', '菜花', '第一季') D4_菜花_第一季
# ('D4', '包菜', '第一季') D4_包菜_第一季
# ('D4', '油麦菜', '第一季') D4_油麦菜_第一季
# ('D4', '小青菜', '第一季') D4_小青菜_第一季
# ('D4', '黄瓜', '第一季') D4_黄瓜_第一季
# ('D4', '生菜 ', '第一季') D4_生菜__第一季
# ('D4', '辣椒', '第一季') D4_辣椒_第一季
# ('D4', '空心菜', '第一季') D4_空心菜_第一季
# ('D4', '黄心菜', '第一季') D4_黄心菜_第一季
# ('D4', '芹菜', '第一季') D4_芹菜_第一季
# ('D4', '大白菜', '第一季') D4_大白菜_第一季
# ('D4', '白萝卜', '第一季') D4_白萝卜_第一季
# ('D4', '红萝卜', '第一季') D4_红萝卜_第一季
# ('D4', '榆黄菇', '第一季') D4_榆黄菇_第一季
# ('D4', '香菇', '第一季') D4_香菇_第一季
# ('D4', '白灵菇', '第一季') D4_白灵菇_第一季
# ('D4', '羊肚菌', '第一季') D4_羊肚菌_第一季
# ('D4', '黄豆', '第二季') D4_黄豆_第二季
# ('D4', '黑豆', '第二季') D4_黑豆_第二季
# ('D4', '红豆', '第二季') D4_红豆_第二季
# ('D4', '绿豆', '第二季') D4_绿豆_第二季
# ('D4', '爬豆', '第二季') D4_爬豆_第二季
# ('D4', '小麦', '第二季') D4_小麦_第二季
# ('D4', '玉米', '第二季') D4_玉米_第二季
# ('D4', '谷子', '第二季') D4_谷子_第二季
# ('D4', '高粱', '第二季') D4_高粱_第二季
# ('D4', '黍子', '第二季') D4_黍子_第二季
# ('D4', '荞麦', '第二季') D4_荞麦_第二季
# ('D4', '南瓜', '第二季') D4_南瓜_第二季
# ('D4', '红薯', '第二季') D4_红薯_第二季
# ('D4', '莜麦', '第二季') D4_莜麦_第二季
# ('D4', '大麦', '第二季') D4_大麦_第二季
# ('D4', '水稻', '第二季') D4_水稻_第二季
# ('D4', '豇豆', '第二季') D4_豇豆_第二季
# ('D4', '刀豆', '第二季') D4_刀豆_第二季
# ('D4', '芸豆', '第二季') D4_芸豆_第二季
# ('D4', '土豆', '第二季') D4_土豆_第二季
# ('D4', '西红柿', '第二季') D4_西红柿_第二季
# ('D4', '茄子', '第二季') D4_茄子_第二季
# ('D4', '菠菜 ', '第二季') D4_菠菜__第二季
# ('D4', '青椒', '第二季') D4_青椒_第二季
# ('D4', '菜花', '第二季') D4_菜花_第二季
# ('D4', '包菜', '第二季') D4_包菜_第二季
# ('D4', '油麦菜', '第二季') D4_油麦菜_第二季
# ('D4', '小青菜', '第二季') D4_小青菜_第二季
# ('D4', '黄瓜', '第二季') D4_黄瓜_第二季
# ('D4', '生菜 ', '第二季') D4_生菜__第二季
# ('D4', '辣椒', '第二季') D4_辣椒_第二季
# ('D4', '空心菜', '第二季') D4_空心菜_第二季
# ('D4', '黄心菜', '第二季') D4_黄心菜_第二季
# ('D4', '芹菜', '第二季') D4_芹菜_第二季
# ('D4', '大白菜', '第二季') D4_大白菜_第二季
# ('D4', '白萝卜', '第二季') D4_白萝卜_第二季
# ('D4', '红萝卜', '第二季') D4_红萝卜_第二季
# ('D4', '榆黄菇', '第二季') D4_榆黄菇_第二季
# ('D4', '香菇', '第二季') D4_香菇_第二季
# ('D4', '白灵菇', '第二季') D4_白灵菇_第二季
# ('D4', '羊肚菌', '第二季') D4_羊肚菌_第二季
# ('D5', '黄豆', '单季') D5_黄豆_单季
# ('D5', '黑豆', '单季') D5_黑豆_单季
# ('D5', '红豆', '单季') D5_红豆_单季
# ('D5', '绿豆', '单季') D5_绿豆_单季
# ('D5', '爬豆', '单季') D5_爬豆_单季
# ('D5', '小麦', '单季') D5_小麦_单季
# ('D5', '玉米', '单季') D5_玉米_单季
# ('D5', '谷子', '单季') D5_谷子_单季
# ('D5', '高粱', '单季') D5_高粱_单季
# ('D5', '黍子', '单季') D5_黍子_单季
# ('D5', '荞麦', '单季') D5_荞麦_单季
# ('D5', '南瓜', '单季') D5_南瓜_单季
# ('D5', '红薯', '单季') D5_红薯_单季
# ('D5', '莜麦', '单季') D5_莜麦_单季
# ('D5', '大麦', '单季') D5_大麦_单季
# ('D5', '水稻', '单季') D5_水稻_单季
# ('D5', '豇豆', '单季') D5_豇豆_单季
# ('D5', '刀豆', '单季') D5_刀豆_单季
# ('D5', '芸豆', '单季') D5_芸豆_单季
# ('D5', '土豆', '单季') D5_土豆_单季
# ('D5', '西红柿', '单季') D5_西红柿_单季
# ('D5', '茄子', '单季') D5_茄子_单季
# ('D5', '菠菜 ', '单季') D5_菠菜__单季
# ('D5', '青椒', '单季') D5_青椒_单季
# ('D5', '菜花', '单季') D5_菜花_单季
# ('D5', '包菜', '单季') D5_包菜_单季
# ('D5', '油麦菜', '单季') D5_油麦菜_单季
# ('D5', '小青菜', '单季') D5_小青菜_单季
# ('D5', '黄瓜', '单季') D5_黄瓜_单季
# ('D5', '生菜 ', '单季') D5_生菜__单季
# ('D5', '辣椒', '单季') D5_辣椒_单季
# ('D5', '空心菜', '单季') D5_空心菜_单季
# ('D5', '黄心菜', '单季') D5_黄心菜_单季
# ('D5', '芹菜', '单季') D5_芹菜_单季
# ('D5', '大白菜', '单季') D5_大白菜_单季
# ('D5', '白萝卜', '单季') D5_白萝卜_单季
# ('D5', '红萝卜', '单季') D5_红萝卜_单季
# ('D5', '榆黄菇', '单季') D5_榆黄菇_单季
# ('D5', '香菇', '单季') D5_香菇_单季
# ('D5', '白灵菇', '单季') D5_白灵菇_单季
# ('D5', '羊肚菌', '单季') D5_羊肚菌_单季
# ('D5', '黄豆', '第一季') D5_黄豆_第一季
# ('D5', '黑豆', '第一季') D5_黑豆_第一季
# ('D5', '红豆', '第一季') D5_红豆_第一季
# ('D5', '绿豆', '第一季') D5_绿豆_第一季
# ('D5', '爬豆', '第一季') D5_爬豆_第一季
# ('D5', '小麦', '第一季') D5_小麦_第一季
# ('D5', '玉米', '第一季') D5_玉米_第一季
# ('D5', '谷子', '第一季') D5_谷子_第一季
# ('D5', '高粱', '第一季') D5_高粱_第一季
# ('D5', '黍子', '第一季') D5_黍子_第一季
# ('D5', '荞麦', '第一季') D5_荞麦_第一季
# ('D5', '南瓜', '第一季') D5_南瓜_第一季
# ('D5', '红薯', '第一季') D5_红薯_第一季
# ('D5', '莜麦', '第一季') D5_莜麦_第一季
# ('D5', '大麦', '第一季') D5_大麦_第一季
# ('D5', '水稻', '第一季') D5_水稻_第一季
# ('D5', '豇豆', '第一季') D5_豇豆_第一季
# ('D5', '刀豆', '第一季') D5_刀豆_第一季
# ('D5', '芸豆', '第一季') D5_芸豆_第一季
# ('D5', '土豆', '第一季') D5_土豆_第一季
# ('D5', '西红柿', '第一季') D5_西红柿_第一季
# ('D5', '茄子', '第一季') D5_茄子_第一季
# ('D5', '菠菜 ', '第一季') D5_菠菜__第一季
# ('D5', '青椒', '第一季') D5_青椒_第一季
# ('D5', '菜花', '第一季') D5_菜花_第一季
# ('D5', '包菜', '第一季') D5_包菜_第一季
# ('D5', '油麦菜', '第一季') D5_油麦菜_第一季
# ('D5', '小青菜', '第一季') D5_小青菜_第一季
# ('D5', '黄瓜', '第一季') D5_黄瓜_第一季
# ('D5', '生菜 ', '第一季') D5_生菜__第一季
# ('D5', '辣椒', '第一季') D5_辣椒_第一季
# ('D5', '空心菜', '第一季') D5_空心菜_第一季
# ('D5', '黄心菜', '第一季') D5_黄心菜_第一季
# ('D5', '芹菜', '第一季') D5_芹菜_第一季
# ('D5', '大白菜', '第一季') D5_大白菜_第一季
# ('D5', '白萝卜', '第一季') D5_白萝卜_第一季
# ('D5', '红萝卜', '第一季') D5_红萝卜_第一季
# ...
# ('E14', '青椒', '第二季') E14_青椒_第二季
# ('E14', '菜花', '第二季') E14_菜花_第二季
# ('E14', '包菜', '第二季') E14_包菜_第二季
# ('E14', '油麦菜', '第二季') E14_油麦菜_第二季
# ('E14', '小青菜', '第二季') E14_小青菜_第二季
# ('E14', '黄瓜', '第二季') E14_黄瓜_第二季
# ('E14', '生菜 ', '第二季') E14_生菜__第二季
# ('E14', '辣椒', '第二季') E14_辣椒_第二季
# ('E14', '空心菜', '第二季') E14_空心菜_第二季
# ('E14', '黄心菜', '第二季') E14_黄心菜_第二季
# ('E14', '芹菜', '第二季') E14_芹菜_第二季
# ('E14', '大白菜', '第二季') E14_大白菜_第二季
# ('E14', '白萝卜', '第二季') E14_白萝卜_第二季
# ('E14', '红萝卜', '第二季') E14_红萝卜_第二季
# ('E14', '榆黄菇', '第二季') E14_榆黄菇_第二季
# ('E14', '香菇', '第二季') E14_香菇_第二季
# ('E14', '白灵菇', '第二季') E14_白灵菇_第二季
# ('E14', '羊肚菌', '第二季') E14_羊肚菌_第二季
# ('E15', '黄豆', '第一季') E15_黄豆_第一季
# ('E15', '黑豆', '第一季') E15_黑豆_第一季
# ('E15', '红豆', '第一季') E15_红豆_第一季
# ('E15', '绿豆', '第一季') E15_绿豆_第一季
# ('E15', '爬豆', '第一季') E15_爬豆_第一季
# ('E15', '小麦', '第一季') E15_小麦_第一季
# ('E15', '玉米', '第一季') E15_玉米_第一季
# ('E15', '谷子', '第一季') E15_谷子_第一季
# ('E15', '高粱', '第一季') E15_高粱_第一季
# ('E15', '黍子', '第一季') E15_黍子_第一季
# ('E15', '荞麦', '第一季') E15_荞麦_第一季
# ('E15', '南瓜', '第一季') E15_南瓜_第一季
# ('E15', '红薯', '第一季') E15_红薯_第一季
# ('E15', '莜麦', '第一季') E15_莜麦_第一季
# ('E15', '大麦', '第一季') E15_大麦_第一季
# ('E15', '水稻', '第一季') E15_水稻_第一季
# ('E15', '豇豆', '第一季') E15_豇豆_第一季
# ('E15', '刀豆', '第一季') E15_刀豆_第一季
# ('E15', '芸豆', '第一季') E15_芸豆_第一季
# ('E15', '土豆', '第一季') E15_土豆_第一季
# ('E15', '西红柿', '第一季') E15_西红柿_第一季
# ('E15', '茄子', '第一季') E15_茄子_第一季
# ('E15', '菠菜 ', '第一季') E15_菠菜__第一季
# ('E15', '青椒', '第一季') E15_青椒_第一季
# ('E15', '菜花', '第一季') E15_菜花_第一季
# ('E15', '包菜', '第一季') E15_包菜_第一季
# ('E15', '油麦菜', '第一季') E15_油麦菜_第一季
# ('E15', '小青菜', '第一季') E15_小青菜_第一季
# ('E15', '黄瓜', '第一季') E15_黄瓜_第一季
# ('E15', '生菜 ', '第一季') E15_生菜__第一季
# ('E15', '辣椒', '第一季') E15_辣椒_第一季
# ('E15', '空心菜', '第一季') E15_空心菜_第一季
# ('E15', '黄心菜', '第一季') E15_黄心菜_第一季
# ('E15', '芹菜', '第一季') E15_芹菜_第一季
# ('E15', '大白菜', '第一季') E15_大白菜_第一季
# ('E15', '白萝卜', '第一季') E15_白萝卜_第一季
# ('E15', '红萝卜', '第一季') E15_红萝卜_第一季
# ('E15', '榆黄菇', '第一季') E15_榆黄菇_第一季
# ('E15', '香菇', '第一季') E15_香菇_第一季
# ('E15', '白灵菇', '第一季') E15_白灵菇_第一季
# ('E15', '羊肚菌', '第一季') E15_羊肚菌_第一季
# ('E15', '黄豆', '第二季') E15_黄豆_第二季
# ('E15', '黑豆', '第二季') E15_黑豆_第二季
# ('E15', '红豆', '第二季') E15_红豆_第二季
# ('E15', '绿豆', '第二季') E15_绿豆_第二季
# ('E15', '爬豆', '第二季') E15_爬豆_第二季
# ('E15', '小麦', '第二季') E15_小麦_第二季
# ('E15', '玉米', '第二季') E15_玉米_第二季
# ('E15', '谷子', '第二季') E15_谷子_第二季
# ('E15', '高粱', '第二季') E15_高粱_第二季
# ('E15', '黍子', '第二季') E15_黍子_第二季
# ('E15', '荞麦', '第二季') E15_荞麦_第二季
# ('E15', '南瓜', '第二季') E15_南瓜_第二季
# ('E15', '红薯', '第二季') E15_红薯_第二季
# ('E15', '莜麦', '第二季') E15_莜麦_第二季
# ('E15', '大麦', '第二季') E15_大麦_第二季
# ('E15', '水稻', '第二季') E15_水稻_第二季
# ('E15', '豇豆', '第二季') E15_豇豆_第二季
# ('E15', '刀豆', '第二季') E15_刀豆_第二季
# ('E15', '芸豆', '第二季') E15_芸豆_第二季
# ('E15', '土豆', '第二季') E15_土豆_第二季
# ('E15', '西红柿', '第二季') E15_西红柿_第二季
# ('E15', '茄子', '第二季') E15_茄子_第二季
# ('E15', '菠菜 ', '第二季') E15_菠菜__第二季
# ('E15', '青椒', '第二季') E15_青椒_第二季
# ('E15', '菜花', '第二季') E15_菜花_第二季
# ('E15', '包菜', '第二季') E15_包菜_第二季
# ('E15', '油麦菜', '第二季') E15_油麦菜_第二季
# ('E15', '小青菜', '第二季') E15_小青菜_第二季
# ('E15', '黄瓜', '第二季') E15_黄瓜_第二季
# ('E15', '生菜 ', '第二季') E15_生菜__第二季
# ('E15', '辣椒', '第二季') E15_辣椒_第二季
# ('E15', '空心菜', '第二季') E15_空心菜_第二季
# ('E15', '黄心菜', '第二季') E15_黄心菜_第二季
# ('E15', '芹菜', '第二季') E15_芹菜_第二季
# ('E15', '大白菜', '第二季') E15_大白菜_第二季
# ('E15', '白萝卜', '第二季') E15_白萝卜_第二季
# ('E15', '红萝卜', '第二季') E15_红萝卜_第二季
# ('E15', '榆黄菇', '第二季') E15_榆黄菇_第二季
# ('E15', '香菇', '第二季') E15_香菇_第二季
# ('E15', '白灵菇', '第二季') E15_白灵菇_第二季
# ('E15', '羊肚菌', '第二季') E15_羊肚菌_第二季
# ('E16', '黄豆', '第一季') E16_黄豆_第一季
# ('E16', '黑豆', '第一季') E16_黑豆_第一季
# ('E16', '红豆', '第一季') E16_红豆_第一季
# ('E16', '绿豆', '第一季') E16_绿豆_第一季
# ('E16', '爬豆', '第一季') E16_爬豆_第一季
# ('E16', '小麦', '第一季') E16_小麦_第一季
# ('E16', '玉米', '第一季') E16_玉米_第一季
# ('E16', '谷子', '第一季') E16_谷子_第一季
# ('E16', '高粱', '第一季') E16_高粱_第一季
# ('E16', '黍子', '第一季') E16_黍子_第一季
# ('E16', '荞麦', '第一季') E16_荞麦_第一季
# ('E16', '南瓜', '第一季') E16_南瓜_第一季
# ('E16', '红薯', '第一季') E16_红薯_第一季
# ('E16', '莜麦', '第一季') E16_莜麦_第一季
# ('E16', '大麦', '第一季') E16_大麦_第一季
# ('E16', '水稻', '第一季') E16_水稻_第一季
# ('E16', '豇豆', '第一季') E16_豇豆_第一季
# ('E16', '刀豆', '第一季') E16_刀豆_第一季
# ('E16', '芸豆', '第一季') E16_芸豆_第一季
# ('E16', '土豆', '第一季') E16_土豆_第一季
# ('E16', '西红柿', '第一季') E16_西红柿_第一季
# ('E16', '茄子', '第一季') E16_茄子_第一季
# ('E16', '菠菜 ', '第一季') E16_菠菜__第一季
# ('E16', '青椒', '第一季') E16_青椒_第一季
# ('E16', '菜花', '第一季') E16_菜花_第一季
# ('E16', '包菜', '第一季') E16_包菜_第一季
# ('E16', '油麦菜', '第一季') E16_油麦菜_第一季
# ('E16', '小青菜', '第一季') E16_小青菜_第一季
# ('E16', '黄瓜', '第一季') E16_黄瓜_第一季
# ('E16', '生菜 ', '第一季') E16_生菜__第一季
# ('E16', '辣椒', '第一季') E16_辣椒_第一季
# ('E16', '空心菜', '第一季') E16_空心菜_第一季
# ('E16', '黄心菜', '第一季') E16_黄心菜_第一季
# ('E16', '芹菜', '第一季') E16_芹菜_第一季
# ('E16', '大白菜', '第一季') E16_大白菜_第一季
# ('E16', '白萝卜', '第一季') E16_白萝卜_第一季
# ('E16', '红萝卜', '第一季') E16_红萝卜_第一季
# ('E16', '榆黄菇', '第一季') E16_榆黄菇_第一季
# ('E16', '香菇', '第一季') E16_香菇_第一季
# ('E16', '白灵菇', '第一季') E16_白灵菇_第一季
# ('E16', '羊肚菌', '第一季') E16_羊肚菌_第一季
# ('E16', '黄豆', '第二季') E16_黄豆_第二季
# ('E16', '黑豆', '第二季') E16_黑豆_第二季
# ('E16', '红豆', '第二季') E16_红豆_第二季
# ('E16', '绿豆', '第二季') E16_绿豆_第二季
# ('E16', '爬豆', '第二季') E16_爬豆_第二季
# ('E16', '小麦', '第二季') E16_小麦_第二季
# ('E16', '玉米', '第二季') E16_玉米_第二季
# ('E16', '谷子', '第二季') E16_谷子_第二季
# ('E16', '高粱', '第二季') E16_高粱_第二季
# ('E16', '黍子', '第二季') E16_黍子_第二季
# ('E16', '荞麦', '第二季') E16_荞麦_第二季
# ('E16', '南瓜', '第二季') E16_南瓜_第二季
# ('E16', '红薯', '第二季') E16_红薯_第二季
# ('E16', '莜麦', '第二季') E16_莜麦_第二季
# ('E16', '大麦', '第二季') E16_大麦_第二季
# ('E16', '水稻', '第二季') E16_水稻_第二季
# ('E16', '豇豆', '第二季') E16_豇豆_第二季
# ('E16', '刀豆', '第二季') E16_刀豆_第二季
# ('E16', '芸豆', '第二季') E16_芸豆_第二季
# ('E16', '土豆', '第二季') E16_土豆_第二季
# ('E16', '西红柿', '第二季') E16_西红柿_第二季
# ('E16', '茄子', '第二季') E16_茄子_第二季
# ('E16', '菠菜 ', '第二季') E16_菠菜__第二季
# ('E16', '青椒', '第二季') E16_青椒_第二季
# ('E16', '菜花', '第二季') E16_菜花_第二季
# ('E16', '包菜', '第二季') E16_包菜_第二季
# ('E16', '油麦菜', '第二季') E16_油麦菜_第二季
# ('E16', '小青菜', '第二季') E16_小青菜_第二季
# ('E16', '黄瓜', '第二季') E16_黄瓜_第二季
# ('E16', '生菜 ', '第二季') E16_生菜__第二季
# ('E16', '辣椒', '第二季') E16_辣椒_第二季
# ('E16', '空心菜', '第二季') E16_空心菜_第二季
# ('E16', '黄心菜', '第二季') E16_黄心菜_第二季
# ('E16', '芹菜', '第二季') E16_芹菜_第二季
# ('E16', '大白菜', '第二季') E16_大白菜_第二季
# ('E16', '白萝卜', '第二季') E16_白萝卜_第二季
# ('E16', '红萝卜', '第二季') E16_红萝卜_第二季
# ('E16', '榆黄菇', '第二季') E16_榆黄菇_第二季
# ('E16', '香菇', '第二季') E16_香菇_第二季
# ('E16', '白灵菇', '第二季') E16_白灵菇_第二季
# ('E16', '羊肚菌', '第二季') E16_羊肚菌_第二季
# ('F1', '黄豆', '第一季') F1_黄豆_第一季
# ('F1', '黑豆', '第一季') F1_黑豆_第一季
# ('F1', '红豆', '第一季') F1_红豆_第一季
# ('F1', '绿豆', '第一季') F1_绿豆_第一季
# ('F1', '爬豆', '第一季') F1_爬豆_第一季
# ('F1', '小麦', '第一季') F1_小麦_第一季
# ('F1', '玉米', '第一季') F1_玉米_第一季
# ('F1', '谷子', '第一季') F1_谷子_第一季
# ('F1', '高粱', '第一季') F1_高粱_第一季
# ('F1', '黍子', '第一季') F1_黍子_第一季
# ('F1', '荞麦', '第一季') F1_荞麦_第一季
# ('F1', '南瓜', '第一季') F1_南瓜_第一季
# ('F1', '红薯', '第一季') F1_红薯_第一季
# ('F1', '莜麦', '第一季') F1_莜麦_第一季
# ('F1', '大麦', '第一季') F1_大麦_第一季
# ('F1', '水稻', '第一季') F1_水稻_第一季
# ('F1', '豇豆', '第一季') F1_豇豆_第一季
# ('F1', '刀豆', '第一季') F1_刀豆_第一季
# ('F1', '芸豆', '第一季') F1_芸豆_第一季
# ('F1', '土豆', '第一季') F1_土豆_第一季
# ('F1', '西红柿', '第一季') F1_西红柿_第一季
# ('F1', '茄子', '第一季') F1_茄子_第一季
# ('F1', '菠菜 ', '第一季') F1_菠菜__第一季
# ('F1', '青椒', '第一季') F1_青椒_第一季
# ('F1', '菜花', '第一季') F1_菜花_第一季
# ('F1', '包菜', '第一季') F1_包菜_第一季
# ('F1', '油麦菜', '第一季') F1_油麦菜_第一季
# ('F1', '小青菜', '第一季') F1_小青菜_第一季
# ('F1', '黄瓜', '第一季') F1_黄瓜_第一季
# ('F1', '生菜 ', '第一季') F1_生菜__第一季
# ('F1', '辣椒', '第一季') F1_辣椒_第一季
# ('F1', '空心菜', '第一季') F1_空心菜_第一季
# ('F1', '黄心菜', '第一季') F1_黄心菜_第一季
# ('F1', '芹菜', '第一季') F1_芹菜_第一季
# ('F1', '大白菜', '第一季') F1_大白菜_第一季
# ('F1', '白萝卜', '第一季') F1_白萝卜_第一季
# ('F1', '红萝卜', '第一季') F1_红萝卜_第一季
# ('F1', '榆黄菇', '第一季') F1_榆黄菇_第一季
# ('F1', '香菇', '第一季') F1_香菇_第一季
# ('F1', '白灵菇', '第一季') F1_白灵菇_第一季
# ('F1', '羊肚菌', '第一季') F1_羊肚菌_第一季
# ('F1', '黄豆', '第二季') F1_黄豆_第二季
# ('F1', '黑豆', '第二季') F1_黑豆_第二季
# ('F1', '红豆', '第二季') F1_红豆_第二季
# ('F1', '绿豆', '第二季') F1_绿豆_第二季
# ('F1', '爬豆', '第二季') F1_爬豆_第二季
# ('F1', '小麦', '第二季') F1_小麦_第二季
# ('F1', '玉米', '第二季') F1_玉米_第二季
# ('F1', '谷子', '第二季') F1_谷子_第二季
# ('F1', '高粱', '第二季') F1_高粱_第二季
# ('F1', '黍子', '第二季') F1_黍子_第二季
# ('F1', '荞麦', '第二季') F1_荞麦_第二季
# ('F1', '南瓜', '第二季') F1_南瓜_第二季
# ('F1', '红薯', '第二季') F1_红薯_第二季
# ('F1', '莜麦', '第二季') F1_莜麦_第二季
# ('F1', '大麦', '第二季') F1_大麦_第二季
# ('F1', '水稻', '第二季') F1_水稻_第二季
# ('F1', '豇豆', '第二季') F1_豇豆_第二季
# ('F1', '刀豆', '第二季') F1_刀豆_第二季
# ('F1', '芸豆', '第二季') F1_芸豆_第二季
# ('F1', '土豆', '第二季') F1_土豆_第二季
# ('F1', '西红柿', '第二季') F1_西红柿_第二季
# ('F1', '茄子', '第二季') F1_茄子_第二季
# ('F1', '菠菜 ', '第二季') F1_菠菜__第二季
# ('F1', '青椒', '第二季') F1_青椒_第二季
# ('F1', '菜花', '第二季') F1_菜花_第二季
# ('F1', '包菜', '第二季') F1_包菜_第二季
# ('F1', '油麦菜', '第二季') F1_油麦菜_第二季
# ('F1', '小青菜', '第二季') F1_小青菜_第二季
# ('F1', '黄瓜', '第二季') F1_黄瓜_第二季
# ('F1', '生菜 ', '第二季') F1_生菜__第二季
# ('F1', '辣椒', '第二季') F1_辣椒_第二季
# ('F1', '空心菜', '第二季') F1_空心菜_第二季
# ('F1', '黄心菜', '第二季') F1_黄心菜_第二季
# ('F1', '芹菜', '第二季') F1_芹菜_第二季
# ('F1', '大白菜', '第二季') F1_大白菜_第二季
# ('F1', '白萝卜', '第二季') F1_白萝卜_第二季
# ('F1', '红萝卜', '第二季') F1_红萝卜_第二季
# ('F1', '榆黄菇', '第二季') F1_榆黄菇_第二季
# ('F1', '香菇', '第二季') F1_香菇_第二季
# ('F1', '白灵菇', '第二季') F1_白灵菇_第二季
# ('F1', '羊肚菌', '第二季') F1_羊肚菌_第二季
# ('F2', '黄豆', '第一季') F2_黄豆_第一季
# ('F2', '黑豆', '第一季') F2_黑豆_第一季
# ('F2', '红豆', '第一季') F2_红豆_第一季
# ('F2', '绿豆', '第一季') F2_绿豆_第一季
# ('F2', '爬豆', '第一季') F2_爬豆_第一季
# ('F2', '小麦', '第一季') F2_小麦_第一季
# ('F2', '玉米', '第一季') F2_玉米_第一季
# ('F2', '谷子', '第一季') F2_谷子_第一季
# ('F2', '高粱', '第一季') F2_高粱_第一季
# ('F2', '黍子', '第一季') F2_黍子_第一季
# ('F2', '荞麦', '第一季') F2_荞麦_第一季
# ('F2', '南瓜', '第一季') F2_南瓜_第一季
# ('F2', '红薯', '第一季') F2_红薯_第一季
# ('F2', '莜麦', '第一季') F2_莜麦_第一季
# ('F2', '大麦', '第一季') F2_大麦_第一季
# ('F2', '水稻', '第一季') F2_水稻_第一季
# ('F2', '豇豆', '第一季') F2_豇豆_第一季
# ('F2', '刀豆', '第一季') F2_刀豆_第一季
# ('F2', '芸豆', '第一季') F2_芸豆_第一季
# ('F2', '土豆', '第一季') F2_土豆_第一季
# ('F2', '西红柿', '第一季') F2_西红柿_第一季
# ('F2', '茄子', '第一季') F2_茄子_第一季
# ('F2', '菠菜 ', '第一季') F2_菠菜__第一季
# ('F2', '青椒', '第一季') F2_青椒_第一季
# ('F2', '菜花', '第一季') F2_菜花_第一季
# ('F2', '包菜', '第一季') F2_包菜_第一季
# ('F2', '油麦菜', '第一季') F2_油麦菜_第一季
# ('F2', '小青菜', '第一季') F2_小青菜_第一季
# ('F2', '黄瓜', '第一季') F2_黄瓜_第一季
# ('F2', '生菜 ', '第一季') F2_生菜__第一季
# ('F2', '辣椒', '第一季') F2_辣椒_第一季
# ('F2', '空心菜', '第一季') F2_空心菜_第一季
# ('F2', '黄心菜', '第一季') F2_黄心菜_第一季
# ('F2', '芹菜', '第一季') F2_芹菜_第一季
# ('F2', '大白菜', '第一季') F2_大白菜_第一季
# ('F2', '白萝卜', '第一季') F2_白萝卜_第一季
# ('F2', '红萝卜', '第一季') F2_红萝卜_第一季
# ('F2', '榆黄菇', '第一季') F2_榆黄菇_第一季
# ('F2', '香菇', '第一季') F2_香菇_第一季
# ('F2', '白灵菇', '第一季') F2_白灵菇_第一季
# ('F2', '羊肚菌', '第一季') F2_羊肚菌_第一季
# ('F2', '黄豆', '第二季') F2_黄豆_第二季
# ('F2', '黑豆', '第二季') F2_黑豆_第二季
# ('F2', '红豆', '第二季') F2_红豆_第二季
# ('F2', '绿豆', '第二季') F2_绿豆_第二季
# ('F2', '爬豆', '第二季') F2_爬豆_第二季
# ('F2', '小麦', '第二季') F2_小麦_第二季
# ('F2', '玉米', '第二季') F2_玉米_第二季
# ('F2', '谷子', '第二季') F2_谷子_第二季
# ('F2', '高粱', '第二季') F2_高粱_第二季
# ('F2', '黍子', '第二季') F2_黍子_第二季
# ('F2', '荞麦', '第二季') F2_荞麦_第二季
# ('F2', '南瓜', '第二季') F2_南瓜_第二季
# ('F2', '红薯', '第二季') F2_红薯_第二季
# ('F2', '莜麦', '第二季') F2_莜麦_第二季
# ('F2', '大麦', '第二季') F2_大麦_第二季
# ('F2', '水稻', '第二季') F2_水稻_第二季
# ('F2', '豇豆', '第二季') F2_豇豆_第二季
# ('F2', '刀豆', '第二季') F2_刀豆_第二季
# ('F2', '芸豆', '第二季') F2_芸豆_第二季
# ('F2', '土豆', '第二季') F2_土豆_第二季
# ('F2', '西红柿', '第二季') F2_西红柿_第二季
# ('F2', '茄子', '第二季') F2_茄子_第二季
# ('F2', '菠菜 ', '第二季') F2_菠菜__第二季
# ('F2', '青椒', '第二季') F2_青椒_第二季
# ('F2', '菜花', '第二季') F2_菜花_第二季
# ('F2', '包菜', '第二季') F2_包菜_第二季
# ('F2', '油麦菜', '第二季') F2_油麦菜_第二季
# ('F2', '小青菜', '第二季') F2_小青菜_第二季
# ('F2', '黄瓜', '第二季') F2_黄瓜_第二季
# ('F2', '生菜 ', '第二季') F2_生菜__第二季
# ('F2', '辣椒', '第二季') F2_辣椒_第二季
# ('F2', '空心菜', '第二季') F2_空心菜_第二季
# ('F2', '黄心菜', '第二季') F2_黄心菜_第二季
# ('F2', '芹菜', '第二季') F2_芹菜_第二季
# ('F2', '大白菜', '第二季') F2_大白菜_第二季
# ('F2', '白萝卜', '第二季') F2_白萝卜_第二季
# ('F2', '红萝卜', '第二季') F2_红萝卜_第二季
# ('F2', '榆黄菇', '第二季') F2_榆黄菇_第二季
# ('F2', '香菇', '第二季') F2_香菇_第二季
# ('F2', '白灵菇', '第二季') F2_白灵菇_第二季
# ('F2', '羊肚菌', '第二季') F2_羊肚菌_第二季
# ('F3', '黄豆', '第一季') F3_黄豆_第一季
# ('F3', '黑豆', '第一季') F3_黑豆_第一季
# ('F3', '红豆', '第一季') F3_红豆_第一季
# ('F3', '绿豆', '第一季') F3_绿豆_第一季
# ('F3', '爬豆', '第一季') F3_爬豆_第一季
# ('F3', '小麦', '第一季') F3_小麦_第一季
# ('F3', '玉米', '第一季') F3_玉米_第一季
# ('F3', '谷子', '第一季') F3_谷子_第一季
# ('F3', '高粱', '第一季') F3_高粱_第一季
# ('F3', '黍子', '第一季') F3_黍子_第一季
# ('F3', '荞麦', '第一季') F3_荞麦_第一季
# ('F3', '南瓜', '第一季') F3_南瓜_第一季
# ('F3', '红薯', '第一季') F3_红薯_第一季
# ('F3', '莜麦', '第一季') F3_莜麦_第一季
# ('F3', '大麦', '第一季') F3_大麦_第一季
# ('F3', '水稻', '第一季') F3_水稻_第一季
# ('F3', '豇豆', '第一季') F3_豇豆_第一季
# ('F3', '刀豆', '第一季') F3_刀豆_第一季
# ('F3', '芸豆', '第一季') F3_芸豆_第一季
# ('F3', '土豆', '第一季') F3_土豆_第一季
# ('F3', '西红柿', '第一季') F3_西红柿_第一季
# ('F3', '茄子', '第一季') F3_茄子_第一季
# ('F3', '菠菜 ', '第一季') F3_菠菜__第一季
# ('F3', '青椒', '第一季') F3_青椒_第一季
# ('F3', '菜花', '第一季') F3_菜花_第一季
# ('F3', '包菜', '第一季') F3_包菜_第一季
# ('F3', '油麦菜', '第一季') F3_油麦菜_第一季
# ('F3', '小青菜', '第一季') F3_小青菜_第一季
# ('F3', '黄瓜', '第一季') F3_黄瓜_第一季
# ('F3', '生菜 ', '第一季') F3_生菜__第一季
# ('F3', '辣椒', '第一季') F3_辣椒_第一季
# ('F3', '空心菜', '第一季') F3_空心菜_第一季
# ('F3', '黄心菜', '第一季') F3_黄心菜_第一季
# ('F3', '芹菜', '第一季') F3_芹菜_第一季
# ('F3', '大白菜', '第一季') F3_大白菜_第一季
# ('F3', '白萝卜', '第一季') F3_白萝卜_第一季
# ('F3', '红萝卜', '第一季') F3_红萝卜_第一季
# ('F3', '榆黄菇', '第一季') F3_榆黄菇_第一季
# ('F3', '香菇', '第一季') F3_香菇_第一季
# ('F3', '白灵菇', '第一季') F3_白灵菇_第一季
# ('F3', '羊肚菌', '第一季') F3_羊肚菌_第一季
# ('F3', '黄豆', '第二季') F3_黄豆_第二季
# ('F3', '黑豆', '第二季') F3_黑豆_第二季
# ('F3', '红豆', '第二季') F3_红豆_第二季
# ('F3', '绿豆', '第二季') F3_绿豆_第二季
# ('F3', '爬豆', '第二季') F3_爬豆_第二季
# ('F3', '小麦', '第二季') F3_小麦_第二季
# ('F3', '玉米', '第二季') F3_玉米_第二季
# ('F3', '谷子', '第二季') F3_谷子_第二季
# ('F3', '高粱', '第二季') F3_高粱_第二季
# ('F3', '黍子', '第二季') F3_黍子_第二季
# ('F3', '荞麦', '第二季') F3_荞麦_第二季
# ('F3', '南瓜', '第二季') F3_南瓜_第二季
# ('F3', '红薯', '第二季') F3_红薯_第二季
# ('F3', '莜麦', '第二季') F3_莜麦_第二季
# ('F3', '大麦', '第二季') F3_大麦_第二季
# ('F3', '水稻', '第二季') F3_水稻_第二季
# ('F3', '豇豆', '第二季') F3_豇豆_第二季
# ('F3', '刀豆', '第二季') F3_刀豆_第二季
# ('F3', '芸豆', '第二季') F3_芸豆_第二季
# ('F3', '土豆', '第二季') F3_土豆_第二季
# ('F3', '西红柿', '第二季') F3_西红柿_第二季
# ('F3', '茄子', '第二季') F3_茄子_第二季
# ('F3', '菠菜 ', '第二季') F3_菠菜__第二季
# ('F3', '青椒', '第二季') F3_青椒_第二季
# ('F3', '菜花', '第二季') F3_菜花_第二季
# ('F3', '包菜', '第二季') F3_包菜_第二季
# ('F3', '油麦菜', '第二季') F3_油麦菜_第二季
# ('F3', '小青菜', '第二季') F3_小青菜_第二季
# ('F3', '黄瓜', '第二季') F3_黄瓜_第二季
# ('F3', '生菜 ', '第二季') F3_生菜__第二季
# ('F3', '辣椒', '第二季') F3_辣椒_第二季
# ('F3', '空心菜', '第二季') F3_空心菜_第二季
# ('F3', '黄心菜', '第二季') F3_黄心菜_第二季
# ('F3', '芹菜', '第二季') F3_芹菜_第二季
# ('F3', '大白菜', '第二季') F3_大白菜_第二季
# ('F3', '白萝卜', '第二季') F3_白萝卜_第二季
# ('F3', '红萝卜', '第二季') F3_红萝卜_第二季
# ('F3', '榆黄菇', '第二季') F3_榆黄菇_第二季
# ('F3', '香菇', '第二季') F3_香菇_第二季
# ('F3', '白灵菇', '第二季') F3_白灵菇_第二季
# ('F3', '羊肚菌', '第二季') F3_羊肚菌_第二季
# ('F4', '黄豆', '第一季') F4_黄豆_第一季
# ('F4', '黑豆', '第一季') F4_黑豆_第一季
# ('F4', '红豆', '第一季') F4_红豆_第一季
# ('F4', '绿豆', '第一季') F4_绿豆_第一季
# ('F4', '爬豆', '第一季') F4_爬豆_第一季
# ('F4', '小麦', '第一季') F4_小麦_第一季
# ('F4', '玉米', '第一季') F4_玉米_第一季
# ('F4', '谷子', '第一季') F4_谷子_第一季
# ('F4', '高粱', '第一季') F4_高粱_第一季
# ('F4', '黍子', '第一季') F4_黍子_第一季
# ('F4', '荞麦', '第一季') F4_荞麦_第一季
# ('F4', '南瓜', '第一季') F4_南瓜_第一季
# ('F4', '红薯', '第一季') F4_红薯_第一季
# ('F4', '莜麦', '第一季') F4_莜麦_第一季
# ('F4', '大麦', '第一季') F4_大麦_第一季
# ('F4', '水稻', '第一季') F4_水稻_第一季
# ('F4', '豇豆', '第一季') F4_豇豆_第一季
# ('F4', '刀豆', '第一季') F4_刀豆_第一季
# ('F4', '芸豆', '第一季') F4_芸豆_第一季
# ('F4', '土豆', '第一季') F4_土豆_第一季
# ('F4', '西红柿', '第一季') F4_西红柿_第一季
# ('F4', '茄子', '第一季') F4_茄子_第一季
# ('F4', '菠菜 ', '第一季') F4_菠菜__第一季
# ('F4', '青椒', '第一季') F4_青椒_第一季
# ('F4', '菜花', '第一季') F4_菜花_第一季
# ('F4', '包菜', '第一季') F4_包菜_第一季
# ('F4', '油麦菜', '第一季') F4_油麦菜_第一季
# ('F4', '小青菜', '第一季') F4_小青菜_第一季
# ('F4', '黄瓜', '第一季') F4_黄瓜_第一季
# ('F4', '生菜 ', '第一季') F4_生菜__第一季
# ('F4', '辣椒', '第一季') F4_辣椒_第一季
# ('F4', '空心菜', '第一季') F4_空心菜_第一季
# ('F4', '黄心菜', '第一季') F4_黄心菜_第一季
# ('F4', '芹菜', '第一季') F4_芹菜_第一季
# ('F4', '大白菜', '第一季') F4_大白菜_第一季
# ('F4', '白萝卜', '第一季') F4_白萝卜_第一季
# ('F4', '红萝卜', '第一季') F4_红萝卜_第一季
# ('F4', '榆黄菇', '第一季') F4_榆黄菇_第一季
# ('F4', '香菇', '第一季') F4_香菇_第一季
# ('F4', '白灵菇', '第一季') F4_白灵菇_第一季
# ('F4', '羊肚菌', '第一季') F4_羊肚菌_第一季
# ('F4', '黄豆', '第二季') F4_黄豆_第二季
# ('F4', '黑豆', '第二季') F4_黑豆_第二季
# ('F4', '红豆', '第二季') F4_红豆_第二季
# ('F4', '绿豆', '第二季') F4_绿豆_第二季
# ('F4', '爬豆', '第二季') F4_爬豆_第二季
# ('F4', '小麦', '第二季') F4_小麦_第二季
# ('F4', '玉米', '第二季') F4_玉米_第二季
# ('F4', '谷子', '第二季') F4_谷子_第二季
# ('F4', '高粱', '第二季') F4_高粱_第二季
# ('F4', '黍子', '第二季') F4_黍子_第二季
# ('F4', '荞麦', '第二季') F4_荞麦_第二季
# ('F4', '南瓜', '第二季') F4_南瓜_第二季
# ('F4', '红薯', '第二季') F4_红薯_第二季
# ('F4', '莜麦', '第二季') F4_莜麦_第二季
# ('F4', '大麦', '第二季') F4_大麦_第二季
# ('F4', '水稻', '第二季') F4_水稻_第二季
# ('F4', '豇豆', '第二季') F4_豇豆_第二季
# ('F4', '刀豆', '第二季') F4_刀豆_第二季
# ('F4', '芸豆', '第二季') F4_芸豆_第二季
# ('F4', '土豆', '第二季') F4_土豆_第二季
# ('F4', '西红柿', '第二季') F4_西红柿_第二季
# ('F4', '茄子', '第二季') F4_茄子_第二季
# ('F4', '菠菜 ', '第二季') F4_菠菜__第二季
# ('F4', '青椒', '第二季') F4_青椒_第二季
# ('F4', '菜花', '第二季') F4_菜花_第二季
# ('F4', '包菜', '第二季') F4_包菜_第二季
# ('F4', '油麦菜', '第二季') F4_油麦菜_第二季
# ('F4', '小青菜', '第二季') F4_小青菜_第二季
# ('F4', '黄瓜', '第二季') F4_黄瓜_第二季
# ('F4', '生菜 ', '第二季') F4_生菜__第二季
# ('F4', '辣椒', '第二季') F4_辣椒_第二季
# ('F4', '空心菜', '第二季') F4_空心菜_第二季
# ('F4', '黄心菜', '第二季') F4_黄心菜_第二季
# ('F4', '芹菜', '第二季') F4_芹菜_第二季
# ('F4', '大白菜', '第二季') F4_大白菜_第二季
# ('F4', '白萝卜', '第二季') F4_白萝卜_第二季
# ('F4', '红萝卜', '第二季') F4_红萝卜_第二季
# ('F4', '榆黄菇', '第二季') F4_榆黄菇_第二季
# ('F4', '香菇', '第二季') F4_香菇_第二季
# ('F4', '白灵菇', '第二季') F4_白灵菇_第二季
# ('F4', '羊肚菌', '第二季') F4_羊肚菌_第二季

# %%
print([variables[(field.field_name, crop.crop_name, field.season)] for crop in crops for field in new_fields])
# print([variables[(field.field_name, crop.crop_name, field.season)] * crop.crop_price for crop in crops for field in new_fields for crop in crops])
# print([total_yield[crop.crop_name] for crop in crops])
# Out:
# [A1_黄豆_单季, A2_黄豆_单季, A3_黄豆_单季, A4_黄豆_单季, A5_黄豆_单季, A6_黄豆_单季, B1_黄豆_单季, B2_黄豆_单季, B3_黄豆_单季, B4_黄豆_单季, B5_黄豆_单季, B6_黄豆_单季, B7_黄豆_单季, B8_黄豆_单季, B9_黄豆_单季, B10_黄豆_单季, B11_黄豆_单季, B12_黄豆_单季, B13_黄豆_单季, B14_黄豆_单季, C1_黄豆_单季, C2_黄豆_单季, C3_黄豆_单季, C4_黄豆_单季, C5_黄豆_单季, C6_黄豆_单季, D1_黄豆_单季, D1_黄豆_第一季, D1_黄豆_第二季, D2_黄豆_单季, D2_黄豆_第一季, D2_黄豆_第二季, D3_黄豆_单季, D3_黄豆_第一季, D3_黄豆_第二季, D4_黄豆_单季, D4_黄豆_第一季, D4_黄豆_第二季, D5_黄豆_单季, D5_黄豆_第一季, D5_黄豆_第二季, D6_黄豆_单季, D6_黄豆_第一季, D6_黄豆_第二季, D7_黄豆_单季, D7_黄豆_第一季, D7_黄豆_第二季, D8_黄豆_单季, D8_黄豆_第一季, D8_黄豆_第二季, E1_黄豆_第一季, E1_黄豆_第二季, E2_黄豆_第一季, E2_黄豆_第二季, E3_黄豆_第一季, E3_黄豆_第二季, E4_黄豆_第一季, E4_黄豆_第二季, E5_黄豆_第一季, E5_黄豆_第二季, E6_黄豆_第一季, E6_黄豆_第二季, E7_黄豆_第一季, E7_黄豆_第二季, E8_黄豆_第一季, E8_黄豆_第二季, E9_黄豆_第一季, E9_黄豆_第二季, E10_黄豆_第一季, E10_黄豆_第二季, E11_黄豆_第一季, E11_黄豆_第二季, E12_黄豆_第一季, E12_黄豆_第二季, E13_黄豆_第一季, E13_黄豆_第二季, E14_黄豆_第一季, E14_黄豆_第二季, E15_黄豆_第一季, E15_黄豆_第二季, E16_黄豆_第一季, E16_黄豆_第二季, F1_黄豆_第一季, F1_黄豆_第二季, F2_黄豆_第一季, F2_黄豆_第二季, F3_黄豆_第一季, F3_黄豆_第二季, F4_黄豆_第一季, F4_黄豆_第二季, A1_黑豆_单季, A2_黑豆_单季, A3_黑豆_单季, A4_黑豆_单季, A5_黑豆_单季, A6_黑豆_单季, B1_黑豆_单季, B2_黑豆_单季, B3_黑豆_单季, B4_黑豆_单季, B5_黑豆_单季, B6_黑豆_单季, B7_黑豆_单季, B8_黑豆_单季, B9_黑豆_单季, B10_黑豆_单季, B11_黑豆_单季, B12_黑豆_单季, B13_黑豆_单季, B14_黑豆_单季, C1_黑豆_单季, C2_黑豆_单季, C3_黑豆_单季, C4_黑豆_单季, C5_黑豆_单季, C6_黑豆_单季, D1_黑豆_单季, D1_黑豆_第一季, D1_黑豆_第二季, D2_黑豆_单季, D2_黑豆_第一季, D2_黑豆_第二季, D3_黑豆_单季, D3_黑豆_第一季, D3_黑豆_第二季, D4_黑豆_单季, D4_黑豆_第一季, D4_黑豆_第二季, D5_黑豆_单季, D5_黑豆_第一季, D5_黑豆_第二季, D6_黑豆_单季, D6_黑豆_第一季, D6_黑豆_第二季, D7_黑豆_单季, D7_黑豆_第一季, D7_黑豆_第二季, D8_黑豆_单季, D8_黑豆_第一季, D8_黑豆_第二季, E1_黑豆_第一季, E1_黑豆_第二季, E2_黑豆_第一季, E2_黑豆_第二季, E3_黑豆_第一季, E3_黑豆_第二季, E4_黑豆_第一季, E4_黑豆_第二季, E5_黑豆_第一季, E5_黑豆_第二季, E6_黑豆_第一季, E6_黑豆_第二季, E7_黑豆_第一季, E7_黑豆_第二季, E8_黑豆_第一季, E8_黑豆_第二季, E9_黑豆_第一季, E9_黑豆_第二季, E10_黑豆_第一季, E10_黑豆_第二季, E11_黑豆_第一季, E11_黑豆_第二季, E12_黑豆_第一季, E12_黑豆_第二季, E13_黑豆_第一季, E13_黑豆_第二季, E14_黑豆_第一季, E14_黑豆_第二季, E15_黑豆_第一季, E15_黑豆_第二季, E16_黑豆_第一季, E16_黑豆_第二季, F1_黑豆_第一季, F1_黑豆_第二季, F2_黑豆_第一季, F2_黑豆_第二季, F3_黑豆_第一季, F3_黑豆_第二季, F4_黑豆_第一季, F4_黑豆_第二季, A1_红豆_单季, A2_红豆_单季, A3_红豆_单季, A4_红豆_单季, A5_红豆_单季, A6_红豆_单季, B1_红豆_单季, B2_红豆_单季, B3_红豆_单季, B4_红豆_单季, B5_红豆_单季, B6_红豆_单季, B7_红豆_单季, B8_红豆_单季, B9_红豆_单季, B10_红豆_单季, B11_红豆_单季, B12_红豆_单季, B13_红豆_单季, B14_红豆_单季, C1_红豆_单季, C2_红豆_单季, C3_红豆_单季, C4_红豆_单季, C5_红豆_单季, C6_红豆_单季, D1_红豆_单季, D1_红豆_第一季, D1_红豆_第二季, D2_红豆_单季, D2_红豆_第一季, D2_红豆_第二季, D3_红豆_单季, D3_红豆_第一季, D3_红豆_第二季, D4_红豆_单季, D4_红豆_第一季, D4_红豆_第二季, D5_红豆_单季, D5_红豆_第一季, D5_红豆_第二季, D6_红豆_单季, D6_红豆_第一季, D6_红豆_第二季, D7_红豆_单季, D7_红豆_第一季, D7_红豆_第二季, D8_红豆_单季, D8_红豆_第一季, D8_红豆_第二季, E1_红豆_第一季, E1_红豆_第二季, E2_红豆_第一季, E2_红豆_第二季, E3_红豆_第一季, E3_红豆_第二季, E4_红豆_第一季, E4_红豆_第二季, E5_红豆_第一季, E5_红豆_第二季, E6_红豆_第一季, E6_红豆_第二季, E7_红豆_第一季, E7_红豆_第二季, E8_红豆_第一季, E8_红豆_第二季, E9_红豆_第一季, E9_红豆_第二季, E10_红豆_第一季, E10_红豆_第二季, E11_红豆_第一季, E11_红豆_第二季, E12_红豆_第一季, E12_红豆_第二季, E13_红豆_第一季, E13_红豆_第二季, E14_红豆_第一季, E14_红豆_第二季, E15_红豆_第一季, E15_红豆_第二季, E16_红豆_第一季, E16_红豆_第二季, F1_红豆_第一季, F1_红豆_第二季, F2_红豆_第一季, F2_红豆_第二季, F3_红豆_第一季, F3_红豆_第二季, F4_红豆_第一季, F4_红豆_第二季, A1_绿豆_单季, A2_绿豆_单季, A3_绿豆_单季, A4_绿豆_单季, A5_绿豆_单季, A6_绿豆_单季, B1_绿豆_单季, B2_绿豆_单季, B3_绿豆_单季, B4_绿豆_单季, B5_绿豆_单季, B6_绿豆_单季, B7_绿豆_单季, B8_绿豆_单季, B9_绿豆_单季, B10_绿豆_单季, B11_绿豆_单季, B12_绿豆_单季, B13_绿豆_单季, B14_绿豆_单季, C1_绿豆_单季, C2_绿豆_单季, C3_绿豆_单季, C4_绿豆_单季, C5_绿豆_单季, C6_绿豆_单季, D1_绿豆_单季, D1_绿豆_第一季, D1_绿豆_第二季, D2_绿豆_单季, D2_绿豆_第一季, D2_绿豆_第二季, D3_绿豆_单季, D3_绿豆_第一季, D3_绿豆_第二季, D4_绿豆_单季, D4_绿豆_第一季, D4_绿豆_第二季, D5_绿豆_单季, D5_绿豆_第一季, D5_绿豆_第二季, D6_绿豆_单季, D6_绿豆_第一季, D6_绿豆_第二季, D7_绿豆_单季, D7_绿豆_第一季, D7_绿豆_第二季, D8_绿豆_单季, D8_绿豆_第一季, D8_绿豆_第二季, E1_绿豆_第一季, E1_绿豆_第二季, E2_绿豆_第一季, E2_绿豆_第二季, E3_绿豆_第一季, E3_绿豆_第二季, E4_绿豆_第一季, E4_绿豆_第二季, E5_绿豆_第一季, E5_绿豆_第二季, E6_绿豆_第一季, E6_绿豆_第二季, E7_绿豆_第一季, E7_绿豆_第二季, E8_绿豆_第一季, E8_绿豆_第二季, E9_绿豆_第一季, E9_绿豆_第二季, E10_绿豆_第一季, E10_绿豆_第二季, E11_绿豆_第一季, E11_绿豆_第二季, E12_绿豆_第一季, E12_绿豆_第二季, E13_绿豆_第一季, E13_绿豆_第二季, E14_绿豆_第一季, E14_绿豆_第二季, E15_绿豆_第一季, E15_绿豆_第二季, E16_绿豆_第一季, E16_绿豆_第二季, F1_绿豆_第一季, F1_绿豆_第二季, F2_绿豆_第一季, F2_绿豆_第二季, F3_绿豆_第一季, F3_绿豆_第二季, F4_绿豆_第一季, F4_绿豆_第二季, A1_爬豆_单季, A2_爬豆_单季, A3_爬豆_单季, A4_爬豆_单季, A5_爬豆_单季, A6_爬豆_单季, B1_爬豆_单季, B2_爬豆_单季, B3_爬豆_单季, B4_爬豆_单季, ...

# %%
# 定义目标函数的各个部分
actual_yield = pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] * 
                           get_yield(field.field_name, crop.crop_name) for field in new_fields for crop in crops])

# 收入部分：实际销售量 * 作物价格
revenue = pulp.lpSum([
    variables[(field.field_name, crop.crop_name, field.season)] * 
    crop.crop_price * min(get_total_yield_2023(crop.crop_name, total_yield_2023), actual_yield)
    for field in new_fields for crop in crops
])

# 成本部分：种植成本
cost = pulp.lpSum([
    variables[(field.field_name, crop.crop_name, field.season)] * get_cost(field, crop)
    for field in new_fields for crop in crops
])

# 超额部分处理：超额部分 * 作物价格 * 系数
excess_handling = pulp.lpSum([
    max(0, actual_yield - get_total_yield_2023(crop.crop_name, total_yield_2023)) * crop.crop_price * 0.5
    for field in new_fields for crop in crops
])

# 总利润 = 收入 - 成本 + 超额部分处理
profit = revenue - cost + excess_handling

# 将目标函数添加到问题中
prob += profit
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 6
#
#       2 actual_yield = pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] *
#
#       3                            get_yield(field.field_name, crop.crop_name) for field in new_fields for crop in crops])
#
#       5 # 收入部分：实际销售量 * 作物价格
#
# ----> 6 revenue = pulp.lpSum([
#
#       7     variables[(field.field_name, crop.crop_name, field.season)] *
#
#       8     crop.crop_price * min(get_total_yield_2023(crop.crop_name, total_yield_2023), actual_yield)
#
#       9     for field in new_fields for crop in crops
#
#      10 ])
#
#      12 # 成本部分：种植成本
#
#      13 cost = pulp.lpSum([
#
#      14     variables[(field.field_name, crop.crop_name, field.season)] * get_cost(field, crop)
#
#      15     for field in new_fields for crop in crops
#
#      16 ])
#
#
#
# Cell In[13], line 8, in <listcomp>(.0)
#
#       2 actual_yield = pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] *
#
#       3                            get_yield(field.field_name, crop.crop_name) for field in new_fields for crop in crops])
#
#       5 # 收入部分：实际销售量 * 作物价格
#
#       6 revenue = pulp.lpSum([
#
#       7     variables[(field.field_name, crop.crop_name, field.season)] *
#
# ----> 8     crop.crop_price * min(get_total_yield_2023(crop.crop_name, total_yield_2023), actual_yield)
#
#       9     for field in new_fields for crop in crops
#
#      10 ])
#
#      12 # 成本部分：种植成本
#
#      13 cost = pulp.lpSum([
#
#      14     variables[(field.field_name, crop.crop_name, field.season)] * get_cost(field, crop)
#
#      15     for field in new_fields for crop in crops
#
#      16 ])
#
#
#
# TypeError: '>' not supported between instances of 'float' and 'LpAffineExpression'

# %%
# 添加约束条件
# 地块面积限制
for field in new_fields:
    prob += pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] for crop in crops]) <= field.field_area

# 作物种植限制
for field in new_fields:
    for crop in crops:
        if not check_crop_constraints(field, crop):
            prob += variables[(field.field_name, crop.crop_name, field.season)] == 0

# 重茬限制
for field in new_fields:
    for crop in crops:
        if not check_rotation_constraints(field, crop):
            prob += variables[(field.field_name, crop.crop_name, field.season)] == 0

# 豆类作物种植要求
for field in new_fields:
    prob += pulp.lpSum([variables[(field.field_name, crop.crop_name, field.season)] for crop in crops if crop.crop_type in ['粮食（豆类）', '蔬菜（豆类）']]) >= 1

# 求解问题
prob.solve()

# 打印结果
print("Status:", pulp.LpStatus[prob.status])
for v in prob.variables():
    if v.varValue > 0:
        print(v.name, "=", v.varValue)

# 更新 new_fields 列表中的种植情况
for field in new_fields:
    field.planted_crop = []
    for crop in crops:
        var_name = f"{field.field_name}_{crop.crop_name}_{field.season}"
        if variables[(field.field_name, crop.crop_name, field.season)].varValue > 0:
            field.planted_crop.append([crop.crop_name, variables[(field.field_name, crop.crop_name, field.season)].varValue])
